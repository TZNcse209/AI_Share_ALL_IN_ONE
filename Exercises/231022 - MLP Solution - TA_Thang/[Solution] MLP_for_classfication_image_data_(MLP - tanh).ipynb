# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/drive/MyDrive/Data/FER-2013.zip"
# Out:
# replace test/angry/PrivateTest_10131363.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace test/angry/PrivateTest_10304478.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace test/angry/PrivateTest_10304478.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng tf.data

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Resize
from torchvision.io import read_image
import os
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)

# %%
batch_size = 256
img_height = 180
img_width = 180
image_count = 28709
train_dir = "/content/train"
val_dir = "/content/test"

# %%
class ImageDataset(Dataset):
    def __init__(self, img_dir, norm):
        self.resize = Resize((img_height, img_width))
        self.norm = norm
        self.img_dir = img_dir
        self.classes = os.listdir(img_dir)
        self.image_files = [(os.path.join(cls, img), cls) for cls in self.classes for img in os.listdir(os.path.join(img_dir, cls))]
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.idx_to_class = {idx:cls  for cls, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path, cls = self.image_files[idx]
        image = self.resize(read_image(os.path.join(self.img_dir, img_path)))
        image = image.type(torch.float32)
        label = self.class_to_idx[cls]
        if self.norm:
            image = (image/127.5) - 1
        return image, label

# %%
train_dataset = ImageDataset(train_dir, True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = ImageDataset(val_dir, True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
image_batch, label_batch = next(iter(train_loader))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(train_dataset.idx_to_class[label.item()])
  plt.axis("off")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# ##### MLP - tanh

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims*4)
        self.linear2 = nn.Linear(hidden_dims*4, hidden_dims*2)
        self.linear3 = nn.Linear(hidden_dims*2, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = nn.Flatten()(x)
        x = self.linear1(x)
        x = self.tanh(x)
        x = self.linear2(x)
        x = self.tanh(x)
        x = self.linear3(x)
        x = self.tanh(x)
        out = self.output(x)
        return out.squeeze(1)

model = MLP(input_dims=180*180, hidden_dims=256, output_dims=7).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.006)

# %%
num_epochs = 100
train_losses = []
train_acc = []
val_losses = []
val_acc = []
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    accuracy = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        accuracy += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    accuracy /= cnt
    train_acc.append(accuracy)


    model.eval()
    val_loss = 0.0
    val_accuracy = 0
    cnt = 0
    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)
            val_loss += loss.item()
            val_accuracy += (torch.argmax(outputs, 1) == y).sum().item()
            cnt += len(y)
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_accuracy /= cnt
    val_acc.append(val_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {train_loss:.4f},  Train_Acc: {accuracy:.4f}, Val_Loss: {val_loss:.4f},  Val_Acc: {val_accuracy:.4f}")
# Out:
# Epoch 1/100, Train_Loss: 1.8414,  Train_Acc: 0.2535, Val_Loss: 1.7933,  Val_Acc: 0.2779
# Epoch 2/100, Train_Loss: 1.7761,  Train_Acc: 0.2929, Val_Loss: 1.7460,  Val_Acc: 0.3140
# Epoch 3/100, Train_Loss: 1.7359,  Train_Acc: 0.3212, Val_Loss: 1.7121,  Val_Acc: 0.3391
# Epoch 4/100, Train_Loss: 1.7061,  Train_Acc: 0.3396, Val_Loss: 1.6867,  Val_Acc: 0.3593
# Epoch 5/100, Train_Loss: 1.6831,  Train_Acc: 0.3523, Val_Loss: 1.6673,  Val_Acc: 0.3657
# Epoch 6/100, Train_Loss: 1.6685,  Train_Acc: 0.3573, Val_Loss: 1.6593,  Val_Acc: 0.3654
# Epoch 7/100, Train_Loss: 1.6584,  Train_Acc: 0.3613, Val_Loss: 1.6538,  Val_Acc: 0.3670
# Epoch 8/100, Train_Loss: 1.6496,  Train_Acc: 0.3665, Val_Loss: 1.6438,  Val_Acc: 0.3665
# Epoch 9/100, Train_Loss: 1.6424,  Train_Acc: 0.3687, Val_Loss: 1.6432,  Val_Acc: 0.3688
# Epoch 10/100, Train_Loss: 1.6369,  Train_Acc: 0.3708, Val_Loss: 1.6327,  Val_Acc: 0.3771
# Epoch 11/100, Train_Loss: 1.6307,  Train_Acc: 0.3719, Val_Loss: 1.6342,  Val_Acc: 0.3746
# Epoch 12/100, Train_Loss: 1.6261,  Train_Acc: 0.3760, Val_Loss: 1.6262,  Val_Acc: 0.3700
# Epoch 13/100, Train_Loss: 1.6203,  Train_Acc: 0.3794, Val_Loss: 1.6228,  Val_Acc: 0.3777
# Epoch 14/100, Train_Loss: 1.6169,  Train_Acc: 0.3803, Val_Loss: 1.6238,  Val_Acc: 0.3766
# Epoch 15/100, Train_Loss: 1.6131,  Train_Acc: 0.3814, Val_Loss: 1.6177,  Val_Acc: 0.3796
# Epoch 16/100, Train_Loss: 1.6088,  Train_Acc: 0.3845, Val_Loss: 1.6198,  Val_Acc: 0.3798
# Epoch 17/100, Train_Loss: 1.6053,  Train_Acc: 0.3848, Val_Loss: 1.6123,  Val_Acc: 0.3813
# Epoch 18/100, Train_Loss: 1.5983,  Train_Acc: 0.3860, Val_Loss: 1.6175,  Val_Acc: 0.3767
# Epoch 19/100, Train_Loss: 1.5950,  Train_Acc: 0.3887, Val_Loss: 1.6077,  Val_Acc: 0.3845
# Epoch 20/100, Train_Loss: 1.5896,  Train_Acc: 0.3909, Val_Loss: 1.6125,  Val_Acc: 0.3768
# Epoch 21/100, Train_Loss: 1.5875,  Train_Acc: 0.3905, Val_Loss: 1.6028,  Val_Acc: 0.3787
# Epoch 22/100, Train_Loss: 1.5840,  Train_Acc: 0.3931, Val_Loss: 1.5998,  Val_Acc: 0.3885
# Epoch 23/100, Train_Loss: 1.5792,  Train_Acc: 0.3954, Val_Loss: 1.5997,  Val_Acc: 0.3841
# Epoch 24/100, Train_Loss: 1.5779,  Train_Acc: 0.3977, Val_Loss: 1.6073,  Val_Acc: 0.3849
# Epoch 25/100, Train_Loss: 1.5710,  Train_Acc: 0.3965, Val_Loss: 1.5979,  Val_Acc: 0.3859
# Epoch 26/100, Train_Loss: 1.5681,  Train_Acc: 0.3974, Val_Loss: 1.6016,  Val_Acc: 0.3807
# Epoch 27/100, Train_Loss: 1.5626,  Train_Acc: 0.4007, Val_Loss: 1.5973,  Val_Acc: 0.3849
# Epoch 28/100, Train_Loss: 1.5616,  Train_Acc: 0.4023, Val_Loss: 1.6003,  Val_Acc: 0.3841
# Epoch 29/100, Train_Loss: 1.5582,  Train_Acc: 0.4058, Val_Loss: 1.5980,  Val_Acc: 0.3845
# Epoch 30/100, Train_Loss: 1.5532,  Train_Acc: 0.4069, Val_Loss: 1.6009,  Val_Acc: 0.3855
# Epoch 31/100, Train_Loss: 1.5500,  Train_Acc: 0.4074, Val_Loss: 1.6143,  Val_Acc: 0.3700
# Epoch 32/100, Train_Loss: 1.5447,  Train_Acc: 0.4093, Val_Loss: 1.5990,  Val_Acc: 0.3778
# Epoch 33/100, Train_Loss: 1.5426,  Train_Acc: 0.4104, Val_Loss: 1.5936,  Val_Acc: 0.3881
# Epoch 34/100, Train_Loss: 1.5412,  Train_Acc: 0.4112, Val_Loss: 1.5925,  Val_Acc: 0.3862
# Epoch 35/100, Train_Loss: 1.5344,  Train_Acc: 0.4155, Val_Loss: 1.5873,  Val_Acc: 0.3895
# Epoch 36/100, Train_Loss: 1.5290,  Train_Acc: 0.4178, Val_Loss: 1.6088,  Val_Acc: 0.3725
# Epoch 37/100, Train_Loss: 1.5256,  Train_Acc: 0.4187, Val_Loss: 1.5785,  Val_Acc: 0.3865
# Epoch 38/100, Train_Loss: 1.5211,  Train_Acc: 0.4198, Val_Loss: 1.5851,  Val_Acc: 0.3852
# Epoch 39/100, Train_Loss: 1.5151,  Train_Acc: 0.4222, Val_Loss: 1.5910,  Val_Acc: 0.3789
# Epoch 40/100, Train_Loss: 1.5117,  Train_Acc: 0.4248, Val_Loss: 1.5816,  Val_Acc: 0.3938
# Epoch 41/100, Train_Loss: 1.5062,  Train_Acc: 0.4275, Val_Loss: 1.5751,  Val_Acc: 0.3862
# Epoch 42/100, Train_Loss: 1.5019,  Train_Acc: 0.4314, Val_Loss: 1.5896,  Val_Acc: 0.3858
# Epoch 43/100, Train_Loss: 1.4958,  Train_Acc: 0.4328, Val_Loss: 1.5717,  Val_Acc: 0.3888
# Epoch 44/100, Train_Loss: 1.4898,  Train_Acc: 0.4355, Val_Loss: 1.5734,  Val_Acc: 0.3873
# Epoch 45/100, Train_Loss: 1.4851,  Train_Acc: 0.4359, Val_Loss: 1.6292,  Val_Acc: 0.3660
# Epoch 46/100, Train_Loss: 1.4816,  Train_Acc: 0.4388, Val_Loss: 1.5845,  Val_Acc: 0.3866
# Epoch 47/100, Train_Loss: 1.4726,  Train_Acc: 0.4412, Val_Loss: 1.5969,  Val_Acc: 0.3738
# Epoch 48/100, Train_Loss: 1.4675,  Train_Acc: 0.4434, Val_Loss: 1.6147,  Val_Acc: 0.3789
# Epoch 49/100, Train_Loss: 1.4619,  Train_Acc: 0.4460, Val_Loss: 1.5830,  Val_Acc: 0.3862
# Epoch 50/100, Train_Loss: 1.4540,  Train_Acc: 0.4486, Val_Loss: 1.6186,  Val_Acc: 0.3689
# Epoch 51/100, Train_Loss: 1.4454,  Train_Acc: 0.4532, Val_Loss: 1.5753,  Val_Acc: 0.3933
# Epoch 52/100, Train_Loss: 1.4401,  Train_Acc: 0.4580, Val_Loss: 1.5540,  Val_Acc: 0.3912
# Epoch 53/100, Train_Loss: 1.4338,  Train_Acc: 0.4579, Val_Loss: 1.5648,  Val_Acc: 0.3899
# Epoch 54/100, Train_Loss: 1.4272,  Train_Acc: 0.4621, Val_Loss: 1.7267,  Val_Acc: 0.3536
# Epoch 55/100, Train_Loss: 1.4212,  Train_Acc: 0.4643, Val_Loss: 1.6005,  Val_Acc: 0.3840
# Epoch 56/100, Train_Loss: 1.4105,  Train_Acc: 0.4699, Val_Loss: 1.6346,  Val_Acc: 0.3700
# Epoch 57/100, Train_Loss: 1.4010,  Train_Acc: 0.4738, Val_Loss: 1.5900,  Val_Acc: 0.3926
# Epoch 58/100, Train_Loss: 1.3953,  Train_Acc: 0.4753, Val_Loss: 1.5868,  Val_Acc: 0.3863
# Epoch 59/100, Train_Loss: 1.3841,  Train_Acc: 0.4821, Val_Loss: 1.6208,  Val_Acc: 0.3796
# Epoch 60/100, Train_Loss: 1.3807,  Train_Acc: 0.4829, Val_Loss: 1.6038,  Val_Acc: 0.3813
# Epoch 61/100, Train_Loss: 1.3678,  Train_Acc: 0.4867, Val_Loss: 1.5718,  Val_Acc: 0.3954
# Epoch 62/100, Train_Loss: 1.3583,  Train_Acc: 0.4936, Val_Loss: 1.6027,  Val_Acc: 0.3819
# Epoch 63/100, Train_Loss: 1.3577,  Train_Acc: 0.4916, Val_Loss: 1.6132,  Val_Acc: 0.3813
# Epoch 64/100, Train_Loss: 1.3401,  Train_Acc: 0.5018, Val_Loss: 1.6371,  Val_Acc: 0.3761
# Epoch 65/100, Train_Loss: 1.3364,  Train_Acc: 0.5042, Val_Loss: 1.5373,  Val_Acc: 0.4082
# Epoch 66/100, Train_Loss: 1.3233,  Train_Acc: 0.5109, Val_Loss: 1.6590,  Val_Acc: 0.3690
# Epoch 67/100, Train_Loss: 1.3184,  Train_Acc: 0.5115, Val_Loss: 1.6540,  Val_Acc: 0.3682
# Epoch 68/100, Train_Loss: 1.2981,  Train_Acc: 0.5207, Val_Loss: 1.6197,  Val_Acc: 0.3894
# Epoch 69/100, Train_Loss: 1.2960,  Train_Acc: 0.5211, Val_Loss: 1.6204,  Val_Acc: 0.3831
# Epoch 70/100, Train_Loss: 1.2810,  Train_Acc: 0.5274, Val_Loss: 1.5963,  Val_Acc: 0.3977
# Epoch 71/100, Train_Loss: 1.2686,  Train_Acc: 0.5317, Val_Loss: 1.5727,  Val_Acc: 0.4033
# Epoch 72/100, Train_Loss: 1.2682,  Train_Acc: 0.5337, Val_Loss: 1.6148,  Val_Acc: 0.3750
# Epoch 73/100, Train_Loss: 1.2400,  Train_Acc: 0.5450, Val_Loss: 1.6395,  Val_Acc: 0.3853
# Epoch 74/100, Train_Loss: 1.2409,  Train_Acc: 0.5456, Val_Loss: 1.6273,  Val_Acc: 0.3890
# Epoch 75/100, Train_Loss: 1.2223,  Train_Acc: 0.5551, Val_Loss: 1.6016,  Val_Acc: 0.3954
# Epoch 76/100, Train_Loss: 1.2186,  Train_Acc: 0.5529, Val_Loss: 1.6371,  Val_Acc: 0.4025
# Epoch 77/100, Train_Loss: 1.2089,  Train_Acc: 0.5611, Val_Loss: 1.6607,  Val_Acc: 0.3898
# Epoch 78/100, Train_Loss: 1.1875,  Train_Acc: 0.5675, Val_Loss: 1.6392,  Val_Acc: 0.3867
# Epoch 79/100, Train_Loss: 1.1811,  Train_Acc: 0.5743, Val_Loss: 2.1399,  Val_Acc: 0.2944
# Epoch 80/100, Train_Loss: 1.1678,  Train_Acc: 0.5787, Val_Loss: 1.6283,  Val_Acc: 0.4016
# Epoch 81/100, Train_Loss: 1.1630,  Train_Acc: 0.5823, Val_Loss: 1.9134,  Val_Acc: 0.3346
# Epoch 82/100, Train_Loss: 1.1409,  Train_Acc: 0.5899, Val_Loss: 1.7661,  Val_Acc: 0.3596
# Epoch 83/100, Train_Loss: 1.1279,  Train_Acc: 0.5943, Val_Loss: 1.9629,  Val_Acc: 0.3462
# Epoch 84/100, Train_Loss: 1.1123,  Train_Acc: 0.6039, Val_Loss: 1.6436,  Val_Acc: 0.3975
# Epoch 85/100, Train_Loss: 1.1010,  Train_Acc: 0.6048, Val_Loss: 1.7033,  Val_Acc: 0.3824
# Epoch 86/100, Train_Loss: 1.0908,  Train_Acc: 0.6115, Val_Loss: 1.7996,  Val_Acc: 0.3706
# Epoch 87/100, Train_Loss: 1.0773,  Train_Acc: 0.6179, Val_Loss: 1.6966,  Val_Acc: 0.3961
# Epoch 88/100, Train_Loss: 1.0446,  Train_Acc: 0.6284, Val_Loss: 1.9454,  Val_Acc: 0.3635
# Epoch 89/100, Train_Loss: 1.0447,  Train_Acc: 0.6288, Val_Loss: 1.7580,  Val_Acc: 0.3955
# Epoch 90/100, Train_Loss: 1.0308,  Train_Acc: 0.6404, Val_Loss: 1.7003,  Val_Acc: 0.3966
# Epoch 91/100, Train_Loss: 0.9956,  Train_Acc: 0.6521, Val_Loss: 1.8906,  Val_Acc: 0.3700
# Epoch 92/100, Train_Loss: 1.0070,  Train_Acc: 0.6462, Val_Loss: 1.9579,  Val_Acc: 0.3458
# Epoch 93/100, Train_Loss: 0.9901,  Train_Acc: 0.6556, Val_Loss: 1.9641,  Val_Acc: 0.3580
# Epoch 94/100, Train_Loss: 0.9723,  Train_Acc: 0.6622, Val_Loss: 1.9860,  Val_Acc: 0.3516
# Epoch 95/100, Train_Loss: 0.9514,  Train_Acc: 0.6698, Val_Loss: 1.7686,  Val_Acc: 0.3824
# Epoch 96/100, Train_Loss: 0.9521,  Train_Acc: 0.6697, Val_Loss: 1.7814,  Val_Acc: 0.3883
# Epoch 97/100, Train_Loss: 0.9241,  Train_Acc: 0.6796, Val_Loss: 1.9480,  Val_Acc: 0.3720
# Epoch 98/100, Train_Loss: 0.9141,  Train_Acc: 0.6906, Val_Loss: 1.7600,  Val_Acc: 0.3897
# Epoch 99/100, Train_Loss: 0.8872,  Train_Acc: 0.6983, Val_Loss: 1.8785,  Val_Acc: 0.3794
# Epoch 100/100, Train_Loss: 0.8678,  Train_Acc: 0.7028, Val_Loss: 1.8803,  Val_Acc: 0.3851

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(train_losses, label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(train_acc, label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(val_losses, label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(val_acc, label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)
