# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/drive/MyDrive/Data/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng tf.data

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Resize
from torchvision.io import read_image
import os
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)

# %%
batch_size = 256
img_height = 180
img_width = 180
image_count = 28709
train_dir = "/content/train"
val_dir = "/content/test"

# %%
class ImageDataset(Dataset):
    def __init__(self, img_dir, norm):
        self.resize = Resize((img_height, img_width))
        self.norm = norm
        self.img_dir = img_dir
        self.classes = os.listdir(img_dir)
        self.image_files = [(os.path.join(cls, img), cls) for cls in self.classes for img in os.listdir(os.path.join(img_dir, cls))]
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.idx_to_class = {idx:cls  for cls, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path, cls = self.image_files[idx]
        image = self.resize(read_image(os.path.join(self.img_dir, img_path)))
        image = image.type(torch.float32)
        label = self.class_to_idx[cls]
        if self.norm:
            image = (image/127.5) - 1
        return image, label

# %%
train_dataset = ImageDataset(train_dir, True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = ImageDataset(val_dir, True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
image_batch, label_batch = next(iter(train_loader))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(train_dataset.idx_to_class[label.item()])
  plt.axis("off")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# ##### MLP - tanh

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims*4)
        self.linear2 = nn.Linear(hidden_dims*4, hidden_dims*2)
        self.linear3 = nn.Linear(hidden_dims*2, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = nn.Flatten()(x)
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        x = self.relu(x)
        x = self.linear3(x)
        x = self.relu(x)
        out = self.output(x)
        return out.squeeze(1)

model = MLP(input_dims=180*180, hidden_dims=256, output_dims=7).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.006)

# %%
num_epochs = 100
train_losses = []
train_acc = []
val_losses = []
val_acc = []
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    accuracy = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        accuracy += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    accuracy /= cnt
    train_acc.append(accuracy)


    model.eval()
    val_loss = 0.0
    val_accuracy = 0
    cnt = 0
    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)
            val_loss += loss.item()
            val_accuracy += (torch.argmax(outputs, 1) == y).sum().item()
            cnt += len(y)
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_accuracy /= cnt
    val_acc.append(val_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {train_loss:.4f},  Train_Acc: {accuracy:.4f}, Val_Loss: {val_loss:.4f},  Val_Acc: {val_accuracy:.4f}")
# Out:
# Epoch 1/100, Train_Loss: 1.9060,  Train_Acc: 0.2124, Val_Loss: 1.8622,  Val_Acc: 0.2627
# Epoch 2/100, Train_Loss: 1.8268,  Train_Acc: 0.2608, Val_Loss: 1.8065,  Val_Acc: 0.2611
# Epoch 3/100, Train_Loss: 1.7881,  Train_Acc: 0.2732, Val_Loss: 1.7832,  Val_Acc: 0.2795
# Epoch 4/100, Train_Loss: 1.7677,  Train_Acc: 0.2921, Val_Loss: 1.7636,  Val_Acc: 0.2999
# Epoch 5/100, Train_Loss: 1.7477,  Train_Acc: 0.3061, Val_Loss: 1.7439,  Val_Acc: 0.3247
# Epoch 6/100, Train_Loss: 1.7252,  Train_Acc: 0.3249, Val_Loss: 1.7192,  Val_Acc: 0.3384
# Epoch 7/100, Train_Loss: 1.6999,  Train_Acc: 0.3392, Val_Loss: 1.6945,  Val_Acc: 0.3430
# Epoch 8/100, Train_Loss: 1.6767,  Train_Acc: 0.3492, Val_Loss: 1.6726,  Val_Acc: 0.3541
# Epoch 9/100, Train_Loss: 1.6568,  Train_Acc: 0.3580, Val_Loss: 1.6579,  Val_Acc: 0.3610
# Epoch 10/100, Train_Loss: 1.6403,  Train_Acc: 0.3626, Val_Loss: 1.6459,  Val_Acc: 0.3649
# Epoch 11/100, Train_Loss: 1.6283,  Train_Acc: 0.3692, Val_Loss: 1.6340,  Val_Acc: 0.3725
# Epoch 12/100, Train_Loss: 1.6191,  Train_Acc: 0.3739, Val_Loss: 1.6293,  Val_Acc: 0.3755
# Epoch 13/100, Train_Loss: 1.6074,  Train_Acc: 0.3799, Val_Loss: 1.6231,  Val_Acc: 0.3763
# Epoch 14/100, Train_Loss: 1.5981,  Train_Acc: 0.3835, Val_Loss: 1.6138,  Val_Acc: 0.3837
# Epoch 15/100, Train_Loss: 1.5893,  Train_Acc: 0.3869, Val_Loss: 1.6119,  Val_Acc: 0.3813
# Epoch 16/100, Train_Loss: 1.5820,  Train_Acc: 0.3894, Val_Loss: 1.5959,  Val_Acc: 0.3915
# Epoch 17/100, Train_Loss: 1.5736,  Train_Acc: 0.3938, Val_Loss: 1.5903,  Val_Acc: 0.3950
# Epoch 18/100, Train_Loss: 1.5646,  Train_Acc: 0.3991, Val_Loss: 1.5864,  Val_Acc: 0.3969
# Epoch 19/100, Train_Loss: 1.5558,  Train_Acc: 0.4002, Val_Loss: 1.5832,  Val_Acc: 0.3941
# Epoch 20/100, Train_Loss: 1.5484,  Train_Acc: 0.4034, Val_Loss: 1.5865,  Val_Acc: 0.3948
# Epoch 21/100, Train_Loss: 1.5408,  Train_Acc: 0.4059, Val_Loss: 1.5699,  Val_Acc: 0.4039
# Epoch 22/100, Train_Loss: 1.5324,  Train_Acc: 0.4120, Val_Loss: 1.5682,  Val_Acc: 0.4030
# Epoch 23/100, Train_Loss: 1.5225,  Train_Acc: 0.4168, Val_Loss: 1.5592,  Val_Acc: 0.4067
# Epoch 24/100, Train_Loss: 1.5129,  Train_Acc: 0.4212, Val_Loss: 1.5550,  Val_Acc: 0.4110
# Epoch 25/100, Train_Loss: 1.5067,  Train_Acc: 0.4232, Val_Loss: 1.5496,  Val_Acc: 0.4092
# Epoch 26/100, Train_Loss: 1.4955,  Train_Acc: 0.4285, Val_Loss: 1.5725,  Val_Acc: 0.3947
# Epoch 27/100, Train_Loss: 1.4904,  Train_Acc: 0.4320, Val_Loss: 1.5750,  Val_Acc: 0.3954
# Epoch 28/100, Train_Loss: 1.4813,  Train_Acc: 0.4340, Val_Loss: 1.5816,  Val_Acc: 0.3963
# Epoch 29/100, Train_Loss: 1.4728,  Train_Acc: 0.4396, Val_Loss: 1.5476,  Val_Acc: 0.4104
# Epoch 30/100, Train_Loss: 1.4655,  Train_Acc: 0.4428, Val_Loss: 1.5496,  Val_Acc: 0.4012
# Epoch 31/100, Train_Loss: 1.4547,  Train_Acc: 0.4488, Val_Loss: 1.5430,  Val_Acc: 0.4028
# Epoch 32/100, Train_Loss: 1.4453,  Train_Acc: 0.4500, Val_Loss: 1.5229,  Val_Acc: 0.4160
# Epoch 33/100, Train_Loss: 1.4357,  Train_Acc: 0.4541, Val_Loss: 1.5440,  Val_Acc: 0.4111
# Epoch 34/100, Train_Loss: 1.4291,  Train_Acc: 0.4573, Val_Loss: 1.5411,  Val_Acc: 0.4101
# Epoch 35/100, Train_Loss: 1.4179,  Train_Acc: 0.4610, Val_Loss: 1.5341,  Val_Acc: 0.4163
# Epoch 36/100, Train_Loss: 1.4104,  Train_Acc: 0.4670, Val_Loss: 1.6228,  Val_Acc: 0.3887
# Epoch 37/100, Train_Loss: 1.4025,  Train_Acc: 0.4699, Val_Loss: 1.5593,  Val_Acc: 0.4037
# Epoch 38/100, Train_Loss: 1.3980,  Train_Acc: 0.4723, Val_Loss: 1.5230,  Val_Acc: 0.4156
# Epoch 39/100, Train_Loss: 1.3820,  Train_Acc: 0.4761, Val_Loss: 1.6261,  Val_Acc: 0.3895
# Epoch 40/100, Train_Loss: 1.3814,  Train_Acc: 0.4788, Val_Loss: 1.5712,  Val_Acc: 0.4030
# Epoch 41/100, Train_Loss: 1.3658,  Train_Acc: 0.4850, Val_Loss: 1.5249,  Val_Acc: 0.4179
# Epoch 42/100, Train_Loss: 1.3655,  Train_Acc: 0.4868, Val_Loss: 1.6091,  Val_Acc: 0.3955
# Epoch 43/100, Train_Loss: 1.3515,  Train_Acc: 0.4923, Val_Loss: 1.6527,  Val_Acc: 0.3856
# Epoch 44/100, Train_Loss: 1.3396,  Train_Acc: 0.4986, Val_Loss: 1.5609,  Val_Acc: 0.4074
# Epoch 45/100, Train_Loss: 1.3330,  Train_Acc: 0.5016, Val_Loss: 1.6060,  Val_Acc: 0.3991
# Epoch 46/100, Train_Loss: 1.3368,  Train_Acc: 0.5018, Val_Loss: 1.5549,  Val_Acc: 0.4157
# Epoch 47/100, Train_Loss: 1.3224,  Train_Acc: 0.5030, Val_Loss: 1.5108,  Val_Acc: 0.4315
# Epoch 48/100, Train_Loss: 1.3159,  Train_Acc: 0.5081, Val_Loss: 1.5542,  Val_Acc: 0.4157
# Epoch 49/100, Train_Loss: 1.2913,  Train_Acc: 0.5193, Val_Loss: 1.5575,  Val_Acc: 0.4125
# Epoch 50/100, Train_Loss: 1.2922,  Train_Acc: 0.5197, Val_Loss: 1.6866,  Val_Acc: 0.3710
# Epoch 51/100, Train_Loss: 1.2854,  Train_Acc: 0.5229, Val_Loss: 1.6507,  Val_Acc: 0.3915
# Epoch 52/100, Train_Loss: 1.2692,  Train_Acc: 0.5300, Val_Loss: 1.5335,  Val_Acc: 0.4259
# Epoch 53/100, Train_Loss: 1.2668,  Train_Acc: 0.5287, Val_Loss: 1.6234,  Val_Acc: 0.3849
# Epoch 54/100, Train_Loss: 1.2546,  Train_Acc: 0.5341, Val_Loss: 1.5791,  Val_Acc: 0.4195
# Epoch 55/100, Train_Loss: 1.2464,  Train_Acc: 0.5394, Val_Loss: 1.5713,  Val_Acc: 0.4042
# Epoch 56/100, Train_Loss: 1.2348,  Train_Acc: 0.5431, Val_Loss: 1.7100,  Val_Acc: 0.3975
# Epoch 57/100, Train_Loss: 1.2307,  Train_Acc: 0.5413, Val_Loss: 1.5815,  Val_Acc: 0.4152
# Epoch 58/100, Train_Loss: 1.2139,  Train_Acc: 0.5529, Val_Loss: 1.5920,  Val_Acc: 0.4118
# Epoch 59/100, Train_Loss: 1.2138,  Train_Acc: 0.5562, Val_Loss: 1.7806,  Val_Acc: 0.3668
# Epoch 60/100, Train_Loss: 1.1926,  Train_Acc: 0.5631, Val_Loss: 1.6781,  Val_Acc: 0.3905
# Epoch 61/100, Train_Loss: 1.1852,  Train_Acc: 0.5674, Val_Loss: 1.5244,  Val_Acc: 0.4387
# Epoch 62/100, Train_Loss: 1.1743,  Train_Acc: 0.5721, Val_Loss: 1.6648,  Val_Acc: 0.4125
# Epoch 63/100, Train_Loss: 1.1666,  Train_Acc: 0.5754, Val_Loss: 1.6310,  Val_Acc: 0.4128
# Epoch 64/100, Train_Loss: 1.1544,  Train_Acc: 0.5812, Val_Loss: 1.6311,  Val_Acc: 0.4278
# Epoch 65/100, Train_Loss: 1.1515,  Train_Acc: 0.5833, Val_Loss: 1.5382,  Val_Acc: 0.4356
# Epoch 66/100, Train_Loss: 1.1307,  Train_Acc: 0.5909, Val_Loss: 1.6959,  Val_Acc: 0.3966
# Epoch 67/100, Train_Loss: 1.1280,  Train_Acc: 0.5905, Val_Loss: 1.8918,  Val_Acc: 0.3688
# Epoch 68/100, Train_Loss: 1.1141,  Train_Acc: 0.6003, Val_Loss: 1.6625,  Val_Acc: 0.4156
# Epoch 69/100, Train_Loss: 1.1035,  Train_Acc: 0.6051, Val_Loss: 1.9420,  Val_Acc: 0.3646
# Epoch 70/100, Train_Loss: 1.0950,  Train_Acc: 0.6069, Val_Loss: 1.6457,  Val_Acc: 0.3968
# Epoch 71/100, Train_Loss: 1.0857,  Train_Acc: 0.6086, Val_Loss: 1.7998,  Val_Acc: 0.3865
# Epoch 72/100, Train_Loss: 1.0744,  Train_Acc: 0.6166, Val_Loss: 1.8235,  Val_Acc: 0.3814
# Epoch 73/100, Train_Loss: 1.0656,  Train_Acc: 0.6207, Val_Loss: 1.7192,  Val_Acc: 0.4097
# Epoch 74/100, Train_Loss: 1.0471,  Train_Acc: 0.6237, Val_Loss: 2.0124,  Val_Acc: 0.3756
# Epoch 75/100, Train_Loss: 1.0310,  Train_Acc: 0.6336, Val_Loss: 1.6327,  Val_Acc: 0.4315
# Epoch 76/100, Train_Loss: 1.0262,  Train_Acc: 0.6344, Val_Loss: 1.7234,  Val_Acc: 0.4097
# Epoch 77/100, Train_Loss: 1.0173,  Train_Acc: 0.6394, Val_Loss: 1.8231,  Val_Acc: 0.4003
# Epoch 78/100, Train_Loss: 1.0134,  Train_Acc: 0.6395, Val_Loss: 1.8301,  Val_Acc: 0.3727
# Epoch 79/100, Train_Loss: 0.9972,  Train_Acc: 0.6496, Val_Loss: 1.8200,  Val_Acc: 0.4029
# Epoch 80/100, Train_Loss: 0.9816,  Train_Acc: 0.6549, Val_Loss: 2.2402,  Val_Acc: 0.3877
# Epoch 81/100, Train_Loss: 0.9919,  Train_Acc: 0.6535, Val_Loss: 2.2517,  Val_Acc: 0.3082
# Epoch 82/100, Train_Loss: 0.9669,  Train_Acc: 0.6612, Val_Loss: 1.8312,  Val_Acc: 0.3911
# Epoch 83/100, Train_Loss: 0.9261,  Train_Acc: 0.6802, Val_Loss: 1.8424,  Val_Acc: 0.4100
# Epoch 84/100, Train_Loss: 0.9392,  Train_Acc: 0.6769, Val_Loss: 1.9045,  Val_Acc: 0.3824
# Epoch 85/100, Train_Loss: 0.9151,  Train_Acc: 0.6844, Val_Loss: 2.0961,  Val_Acc: 0.3983
# Epoch 86/100, Train_Loss: 0.9196,  Train_Acc: 0.6814, Val_Loss: 1.8415,  Val_Acc: 0.4147
# Epoch 87/100, Train_Loss: 0.9142,  Train_Acc: 0.6850, Val_Loss: 1.9024,  Val_Acc: 0.4120
# Epoch 88/100, Train_Loss: 0.8865,  Train_Acc: 0.6959, Val_Loss: 1.9196,  Val_Acc: 0.3805
# Epoch 89/100, Train_Loss: 0.8824,  Train_Acc: 0.6944, Val_Loss: 2.0321,  Val_Acc: 0.3600
# Epoch 90/100, Train_Loss: 0.8665,  Train_Acc: 0.7030, Val_Loss: 1.9499,  Val_Acc: 0.4152
# Epoch 91/100, Train_Loss: 0.8614,  Train_Acc: 0.7050, Val_Loss: 1.8385,  Val_Acc: 0.4167
# Epoch 92/100, Train_Loss: 0.8306,  Train_Acc: 0.7184, Val_Loss: 2.2857,  Val_Acc: 0.3722
# Epoch 93/100, Train_Loss: 0.8508,  Train_Acc: 0.7139, Val_Loss: 2.5615,  Val_Acc: 0.3618
# Epoch 94/100, Train_Loss: 0.8078,  Train_Acc: 0.7268, Val_Loss: 1.9266,  Val_Acc: 0.4023
# Epoch 95/100, Train_Loss: 0.8112,  Train_Acc: 0.7266, Val_Loss: 1.9639,  Val_Acc: 0.4025
# Epoch 96/100, Train_Loss: 0.8038,  Train_Acc: 0.7306, Val_Loss: 2.0167,  Val_Acc: 0.3795
# Epoch 97/100, Train_Loss: 0.8019,  Train_Acc: 0.7286, Val_Loss: 2.0152,  Val_Acc: 0.4117
# Epoch 98/100, Train_Loss: 0.7757,  Train_Acc: 0.7383, Val_Loss: 1.7894,  Val_Acc: 0.4305
# Epoch 99/100, Train_Loss: 0.7727,  Train_Acc: 0.7404, Val_Loss: 2.0117,  Val_Acc: 0.4015
# Epoch 100/100, Train_Loss: 0.7757,  Train_Acc: 0.7410, Val_Loss: 2.9067,  Val_Acc: 0.3245

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(train_losses, label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(train_acc, label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(val_losses, label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(val_acc, label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)
