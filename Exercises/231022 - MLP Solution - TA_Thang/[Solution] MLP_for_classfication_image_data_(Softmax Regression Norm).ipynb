# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/drive/MyDrive/Data/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng tf.data

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Resize
from torchvision.io import read_image
import os
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)

# %%
batch_size = 256
img_height = 180
img_width = 180
image_count = 28709
train_dir = "/content/train"
val_dir = "/content/test"

# %%
class ImageDataset(Dataset):
    def __init__(self, img_dir, norm):
        self.resize = Resize((img_height, img_width))
        self.norm = norm
        self.img_dir = img_dir
        self.classes = os.listdir(img_dir)
        self.image_files = [(os.path.join(cls, img), cls) for cls in self.classes for img in os.listdir(os.path.join(img_dir, cls))]
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.idx_to_class = {idx:cls  for cls, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path, cls = self.image_files[idx]
        image = self.resize(read_image(os.path.join(self.img_dir, img_path)))
        image = image.type(torch.float32)
        label = self.class_to_idx[cls]
        if self.norm:
            image = (image/127.5) - 1
        return image, label

# %%
train_dataset = ImageDataset(train_dir, True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = ImageDataset(val_dir, True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
image_batch, label_batch = next(iter(train_loader))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(train_dataset.idx_to_class[label.item()])
  plt.axis("off")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# ##### Softmax Regression Norm

# %%
class SoftMaxRegression(nn.Module):
    def __init__(self, input_dims, num_classes):
        super(SoftMaxRegression, self).__init__()
        self.linear = nn.Linear(input_dims, num_classes)

    def forward(self, x):
        x = nn.Flatten()(x)
        out = self.linear(x)
        return out

model = SoftMaxRegression(input_dims=180*180, num_classes=7).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.006)

# %%
num_epochs = 100
train_losses = []
train_acc = []
val_losses = []
val_acc = []
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    accuracy = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        accuracy += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    accuracy /= cnt
    train_acc.append(accuracy)


    model.eval()
    val_loss = 0.0
    val_accuracy = 0
    cnt = 0
    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)
            val_loss += loss.item()
            val_accuracy += (torch.argmax(outputs, 1) == y).sum().item()
            cnt += len(y)
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_accuracy /= cnt
    val_acc.append(val_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {train_loss:.4f},  Train_Acc: {accuracy:.4f}, Val_Loss: {val_loss:.4f},  Val_Acc: {val_accuracy:.4f}")
# Out:
# Epoch 1/100, Train_Loss: 1.8715,  Train_Acc: 0.2898, Val_Loss: 2.1336,  Val_Acc: 0.2510
# Epoch 2/100, Train_Loss: 1.8023,  Train_Acc: 0.3220, Val_Loss: 1.9762,  Val_Acc: 0.2888
# Epoch 3/100, Train_Loss: 1.8178,  Train_Acc: 0.3223, Val_Loss: 2.1042,  Val_Acc: 0.2600
# Epoch 4/100, Train_Loss: 1.7980,  Train_Acc: 0.3321, Val_Loss: 1.8874,  Val_Acc: 0.3089
# Epoch 5/100, Train_Loss: 1.7776,  Train_Acc: 0.3348, Val_Loss: 2.0499,  Val_Acc: 0.2896
# Epoch 6/100, Train_Loss: 1.7565,  Train_Acc: 0.3402, Val_Loss: 2.0763,  Val_Acc: 0.3001
# Epoch 7/100, Train_Loss: 1.7566,  Train_Acc: 0.3391, Val_Loss: 2.0098,  Val_Acc: 0.3038
# Epoch 8/100, Train_Loss: 1.7430,  Train_Acc: 0.3492, Val_Loss: 2.0146,  Val_Acc: 0.2852
# Epoch 9/100, Train_Loss: 1.7586,  Train_Acc: 0.3464, Val_Loss: 2.3233,  Val_Acc: 0.2888
# Epoch 10/100, Train_Loss: 1.7415,  Train_Acc: 0.3512, Val_Loss: 1.9668,  Val_Acc: 0.3064
# Epoch 11/100, Train_Loss: 1.7396,  Train_Acc: 0.3479, Val_Loss: 1.8571,  Val_Acc: 0.3274
# Epoch 12/100, Train_Loss: 1.7567,  Train_Acc: 0.3461, Val_Loss: 1.9250,  Val_Acc: 0.3001
# Epoch 13/100, Train_Loss: 1.7343,  Train_Acc: 0.3513, Val_Loss: 2.1240,  Val_Acc: 0.2859
# Epoch 14/100, Train_Loss: 1.7371,  Train_Acc: 0.3535, Val_Loss: 1.8836,  Val_Acc: 0.3203
# Epoch 15/100, Train_Loss: 1.7254,  Train_Acc: 0.3555, Val_Loss: 1.8347,  Val_Acc: 0.3139
# Epoch 16/100, Train_Loss: 1.7137,  Train_Acc: 0.3606, Val_Loss: 1.9286,  Val_Acc: 0.2920
# Epoch 17/100, Train_Loss: 1.7415,  Train_Acc: 0.3567, Val_Loss: 2.1506,  Val_Acc: 0.2746
# Epoch 18/100, Train_Loss: 1.7131,  Train_Acc: 0.3611, Val_Loss: 2.0262,  Val_Acc: 0.2974
# Epoch 19/100, Train_Loss: 1.7267,  Train_Acc: 0.3605, Val_Loss: 1.8521,  Val_Acc: 0.3123
# Epoch 20/100, Train_Loss: 1.7275,  Train_Acc: 0.3594, Val_Loss: 2.1433,  Val_Acc: 0.2615
# Epoch 21/100, Train_Loss: 1.7207,  Train_Acc: 0.3574, Val_Loss: 2.1764,  Val_Acc: 0.3082
# Epoch 22/100, Train_Loss: 1.7062,  Train_Acc: 0.3662, Val_Loss: 1.9363,  Val_Acc: 0.3033
# Epoch 23/100, Train_Loss: 1.7032,  Train_Acc: 0.3630, Val_Loss: 1.9477,  Val_Acc: 0.2721
# Epoch 24/100, Train_Loss: 1.7002,  Train_Acc: 0.3636, Val_Loss: 2.3518,  Val_Acc: 0.2923
# Epoch 25/100, Train_Loss: 1.7026,  Train_Acc: 0.3640, Val_Loss: 2.3671,  Val_Acc: 0.2714
# Epoch 26/100, Train_Loss: 1.7081,  Train_Acc: 0.3651, Val_Loss: 1.9362,  Val_Acc: 0.2875
# Epoch 27/100, Train_Loss: 1.6850,  Train_Acc: 0.3718, Val_Loss: 2.0572,  Val_Acc: 0.2967
# Epoch 28/100, Train_Loss: 1.7077,  Train_Acc: 0.3669, Val_Loss: 2.3169,  Val_Acc: 0.2841
# Epoch 29/100, Train_Loss: 1.7090,  Train_Acc: 0.3649, Val_Loss: 1.9238,  Val_Acc: 0.2788
# Epoch 30/100, Train_Loss: 1.6824,  Train_Acc: 0.3731, Val_Loss: 1.9133,  Val_Acc: 0.3068
# Epoch 31/100, Train_Loss: 1.6788,  Train_Acc: 0.3739, Val_Loss: 2.3117,  Val_Acc: 0.2914
# Epoch 32/100, Train_Loss: 1.7005,  Train_Acc: 0.3678, Val_Loss: 1.8857,  Val_Acc: 0.3330
# Epoch 33/100, Train_Loss: 1.7042,  Train_Acc: 0.3655, Val_Loss: 1.8616,  Val_Acc: 0.3270
# Epoch 34/100, Train_Loss: 1.6879,  Train_Acc: 0.3722, Val_Loss: 2.2894,  Val_Acc: 0.2821
# Epoch 35/100, Train_Loss: 1.6728,  Train_Acc: 0.3765, Val_Loss: 2.2635,  Val_Acc: 0.2781
# Epoch 36/100, Train_Loss: 1.6805,  Train_Acc: 0.3736, Val_Loss: 2.0003,  Val_Acc: 0.2906
# Epoch 37/100, Train_Loss: 1.6719,  Train_Acc: 0.3723, Val_Loss: 1.8155,  Val_Acc: 0.3204
# Epoch 38/100, Train_Loss: 1.6815,  Train_Acc: 0.3731, Val_Loss: 2.0559,  Val_Acc: 0.3105
# Epoch 39/100, Train_Loss: 1.6903,  Train_Acc: 0.3709, Val_Loss: 2.4178,  Val_Acc: 0.2934
# Epoch 40/100, Train_Loss: 1.7187,  Train_Acc: 0.3680, Val_Loss: 1.8780,  Val_Acc: 0.3001
# Epoch 41/100, Train_Loss: 1.6623,  Train_Acc: 0.3799, Val_Loss: 1.9999,  Val_Acc: 0.3233
# Epoch 42/100, Train_Loss: 1.6829,  Train_Acc: 0.3734, Val_Loss: 2.2484,  Val_Acc: 0.2601
# Epoch 43/100, Train_Loss: 1.6632,  Train_Acc: 0.3783, Val_Loss: 1.8998,  Val_Acc: 0.3034
# Epoch 44/100, Train_Loss: 1.6593,  Train_Acc: 0.3796, Val_Loss: 2.1726,  Val_Acc: 0.2940
# Epoch 45/100, Train_Loss: 1.6694,  Train_Acc: 0.3824, Val_Loss: 2.0618,  Val_Acc: 0.3080
# Epoch 46/100, Train_Loss: 1.6870,  Train_Acc: 0.3742, Val_Loss: 2.0150,  Val_Acc: 0.2809
# Epoch 47/100, Train_Loss: 1.6824,  Train_Acc: 0.3766, Val_Loss: 2.0887,  Val_Acc: 0.2857
# Epoch 48/100, Train_Loss: 1.6767,  Train_Acc: 0.3776, Val_Loss: 2.1550,  Val_Acc: 0.2972
# Epoch 49/100, Train_Loss: 1.6779,  Train_Acc: 0.3755, Val_Loss: 2.0311,  Val_Acc: 0.3214
# Epoch 50/100, Train_Loss: 1.6730,  Train_Acc: 0.3777, Val_Loss: 2.3126,  Val_Acc: 0.2738
# Epoch 51/100, Train_Loss: 1.6912,  Train_Acc: 0.3769, Val_Loss: 1.8471,  Val_Acc: 0.3169
# Epoch 52/100, Train_Loss: 1.6768,  Train_Acc: 0.3747, Val_Loss: 1.9062,  Val_Acc: 0.3149
# Epoch 53/100, Train_Loss: 1.6918,  Train_Acc: 0.3774, Val_Loss: 2.0156,  Val_Acc: 0.3186
# Epoch 54/100, Train_Loss: 1.6760,  Train_Acc: 0.3783, Val_Loss: 2.7723,  Val_Acc: 0.2640
# Epoch 55/100, Train_Loss: 1.6466,  Train_Acc: 0.3856, Val_Loss: 1.9674,  Val_Acc: 0.2962
# Epoch 56/100, Train_Loss: 1.6848,  Train_Acc: 0.3784, Val_Loss: 2.0697,  Val_Acc: 0.2958
# Epoch 57/100, Train_Loss: 1.6438,  Train_Acc: 0.3890, Val_Loss: 2.1258,  Val_Acc: 0.2973
# Epoch 58/100, Train_Loss: 1.7030,  Train_Acc: 0.3732, Val_Loss: 2.3303,  Val_Acc: 0.2948
# Epoch 59/100, Train_Loss: 1.6702,  Train_Acc: 0.3813, Val_Loss: 2.4172,  Val_Acc: 0.2661
# Epoch 60/100, Train_Loss: 1.6837,  Train_Acc: 0.3746, Val_Loss: 2.0028,  Val_Acc: 0.2899
# Epoch 61/100, Train_Loss: 1.6653,  Train_Acc: 0.3799, Val_Loss: 2.1045,  Val_Acc: 0.2707
# Epoch 62/100, Train_Loss: 1.6508,  Train_Acc: 0.3847, Val_Loss: 1.8577,  Val_Acc: 0.2980
# Epoch 63/100, Train_Loss: 1.6689,  Train_Acc: 0.3819, Val_Loss: 2.2858,  Val_Acc: 0.2903
# Epoch 64/100, Train_Loss: 1.6687,  Train_Acc: 0.3793, Val_Loss: 2.0323,  Val_Acc: 0.3309
# Epoch 65/100, Train_Loss: 1.7016,  Train_Acc: 0.3766, Val_Loss: 2.2848,  Val_Acc: 0.2938
# Epoch 66/100, Train_Loss: 1.6945,  Train_Acc: 0.3770, Val_Loss: 2.0177,  Val_Acc: 0.2896
# Epoch 67/100, Train_Loss: 1.6463,  Train_Acc: 0.3875, Val_Loss: 1.9251,  Val_Acc: 0.3221
# Epoch 68/100, Train_Loss: 1.6652,  Train_Acc: 0.3789, Val_Loss: 1.9091,  Val_Acc: 0.3256
# Epoch 69/100, Train_Loss: 1.6484,  Train_Acc: 0.3882, Val_Loss: 1.9742,  Val_Acc: 0.3086
# Epoch 70/100, Train_Loss: 1.6828,  Train_Acc: 0.3812, Val_Loss: 2.0898,  Val_Acc: 0.3083
# Epoch 71/100, Train_Loss: 1.6814,  Train_Acc: 0.3816, Val_Loss: 1.8914,  Val_Acc: 0.3357
# Epoch 72/100, Train_Loss: 1.6527,  Train_Acc: 0.3853, Val_Loss: 2.1188,  Val_Acc: 0.3217
# Epoch 73/100, Train_Loss: 1.6640,  Train_Acc: 0.3833, Val_Loss: 2.0130,  Val_Acc: 0.2707
# Epoch 74/100, Train_Loss: 1.6492,  Train_Acc: 0.3858, Val_Loss: 2.1907,  Val_Acc: 0.2843
# Epoch 75/100, Train_Loss: 1.6469,  Train_Acc: 0.3880, Val_Loss: 2.1797,  Val_Acc: 0.2955
# Epoch 76/100, Train_Loss: 1.6712,  Train_Acc: 0.3811, Val_Loss: 1.8939,  Val_Acc: 0.3260
# Epoch 77/100, Train_Loss: 1.6812,  Train_Acc: 0.3811, Val_Loss: 2.1625,  Val_Acc: 0.3133
# Epoch 78/100, Train_Loss: 1.6491,  Train_Acc: 0.3862, Val_Loss: 1.7489,  Val_Acc: 0.3455
# Epoch 79/100, Train_Loss: 1.6373,  Train_Acc: 0.3885, Val_Loss: 2.7377,  Val_Acc: 0.2623
# Epoch 80/100, Train_Loss: 1.6502,  Train_Acc: 0.3872, Val_Loss: 1.8902,  Val_Acc: 0.3172
# Epoch 81/100, Train_Loss: 1.6337,  Train_Acc: 0.3909, Val_Loss: 1.9508,  Val_Acc: 0.3105
# Epoch 82/100, Train_Loss: 1.6420,  Train_Acc: 0.3908, Val_Loss: 2.0915,  Val_Acc: 0.2951
# Epoch 83/100, Train_Loss: 1.6363,  Train_Acc: 0.3910, Val_Loss: 2.0216,  Val_Acc: 0.3217
# Epoch 84/100, Train_Loss: 1.6603,  Train_Acc: 0.3845, Val_Loss: 1.8659,  Val_Acc: 0.3305
# Epoch 85/100, Train_Loss: 1.6498,  Train_Acc: 0.3897, Val_Loss: 1.8728,  Val_Acc: 0.3179
# Epoch 86/100, Train_Loss: 1.6302,  Train_Acc: 0.3914, Val_Loss: 2.1205,  Val_Acc: 0.2895
# Epoch 87/100, Train_Loss: 1.6721,  Train_Acc: 0.3853, Val_Loss: 1.9446,  Val_Acc: 0.2921
# Epoch 88/100, Train_Loss: 1.6635,  Train_Acc: 0.3858, Val_Loss: 2.0214,  Val_Acc: 0.3044
# Epoch 89/100, Train_Loss: 1.6498,  Train_Acc: 0.3878, Val_Loss: 1.8527,  Val_Acc: 0.3284
# Epoch 90/100, Train_Loss: 1.6286,  Train_Acc: 0.3924, Val_Loss: 2.2591,  Val_Acc: 0.2820
# Epoch 91/100, Train_Loss: 1.6536,  Train_Acc: 0.3873, Val_Loss: 2.2128,  Val_Acc: 0.2722
# Epoch 92/100, Train_Loss: 1.6227,  Train_Acc: 0.3947, Val_Loss: 2.1889,  Val_Acc: 0.2654
# Epoch 93/100, Train_Loss: 1.6739,  Train_Acc: 0.3854, Val_Loss: 2.0182,  Val_Acc: 0.2994
# Epoch 94/100, Train_Loss: 1.6361,  Train_Acc: 0.3937, Val_Loss: 1.8736,  Val_Acc: 0.3320
# Epoch 95/100, Train_Loss: 1.6416,  Train_Acc: 0.3913, Val_Loss: 1.9246,  Val_Acc: 0.3267
# Epoch 96/100, Train_Loss: 1.6392,  Train_Acc: 0.3901, Val_Loss: 1.9282,  Val_Acc: 0.3041
# Epoch 97/100, Train_Loss: 1.6420,  Train_Acc: 0.3910, Val_Loss: 2.0520,  Val_Acc: 0.3001
# Epoch 98/100, Train_Loss: 1.6411,  Train_Acc: 0.3881, Val_Loss: 1.8319,  Val_Acc: 0.3235
# Epoch 99/100, Train_Loss: 1.6721,  Train_Acc: 0.3850, Val_Loss: 1.9292,  Val_Acc: 0.3424
# Epoch 100/100, Train_Loss: 1.6359,  Train_Acc: 0.3944, Val_Loss: 2.0273,  Val_Acc: 0.3238

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(train_losses, label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(train_acc, label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(val_losses, label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(val_acc, label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)
