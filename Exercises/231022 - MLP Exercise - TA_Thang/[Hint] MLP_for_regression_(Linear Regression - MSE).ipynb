# %% [markdown]
# ## Download data

# %%
# !gdown --id 1fB9P1Ha1ofQiYWU9wkLAxDZTbtp3Gfqz
# Out:
# /home/server-ailab-12gb/miniconda3/envs/Khoa_env/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1fB9P1Ha1ofQiYWU9wkLAxDZTbtp3Gfqz
# To: /home/server-ailab-12gb/Khoa/AIO2023/hint/Final/sol/Auto_MPG_data.csv
# 100%|███████████████████████████████████████| 15.4k/15.4k [00:00<00:00, 806kB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)

# %% [markdown]
# ## Load Data

# %%
dataset = pd.read_csv("/content/Auto_MPG_data.csv")
dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Europe  Japan  USA
# 0          70       0      0    1
# 1          70       0      0    1
# 2          70       0      0    1
# 3          70       0      0    1
# 4          70       0      0    1

# %% [markdown]
# ## Tiền xử lý dữ liệu dạng table

# %% [markdown]
# ### Lấy label và chia bộ dữ liệu train/val

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
val_dataset = dataset.drop(train_dataset.index)

# %%
X_train = train_dataset.copy()
X_val = val_dataset.copy()

y_train = X_train.pop('MPG')
y_val = X_val.pop('MPG')

X_train, y_train = torch.tensor(X_train.values, dtype=torch.float32), torch.tensor(y_train.values, dtype=torch.float32)
X_val, y_val = torch.tensor(X_val.values, dtype=torch.float32), torch.tensor(y_val.values, dtype=torch.float32)

# %% [markdown]
# ### Chuẩn hóa dữ liệu (Data Standardisation)

# %%
_MEAN = X_train.mean(axis=0)
_STD = X_train.std(axis=0)

X_train = ( X_train-_MEAN)/_STD
X_val = ( X_val-_MEAN)/_STD

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        # print(idx)
        return self.X[idx], self.y[idx]

# %%
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

# %% [markdown]
# ## Sử dụng Pytorch để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %% [markdown]
# ### Linear Regression - MSE

# %%
######################### YOUR CODE HERE #########################
# Buil Linear Regression model: dung 1 linear layer input_dims=9, output_dims=1 
class LinearRegression(nn.Module):

##################################################################

model = LinearRegression(input_dims=9, output_dims=1).to(device)
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
def r_squared(y_true, y_pred):
    """
    Compute R^2 score.
    """
    y_true = torch.Tensor(y_true)
    y_pred = torch.Tensor(y_pred)
    mean_true = torch.mean(y_true)
    ss_tot = torch.sum((y_true - mean_true) ** 2)
    ss_res = torch.sum((y_true - y_pred) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

# %%
num_epochs = 100
train_losses = []
val_losses = []
train_r2 = []
val_r2 = []

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    train_target = []
    val_target = []
    train_predict = []
    val_predict = []
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        train_predict.extend(outputs.tolist())
        train_target.extend(y.tolist())
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    train_r2.append(r_squared(train_target, train_predict))
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            val_predict.extend(outputs.tolist())
            val_target.extend(y.tolist())
            loss = criterion(outputs, y)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_r2.append(r_squared(val_target, val_predict))
    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {train_loss:.4f},  Validation Loss: {val_loss:.4f}")
# Out:
# Epoch 1/100, Train_Loss: 182.0890,  Validation Loss: 22.1928
# Epoch 2/100, Train_Loss: 14.7996,  Validation Loss: 10.6945
# Epoch 3/100, Train_Loss: 11.9723,  Validation Loss: 10.6252
# Epoch 4/100, Train_Loss: 12.4202,  Validation Loss: 10.2359
# Epoch 5/100, Train_Loss: 12.4882,  Validation Loss: 10.5411
# Epoch 6/100, Train_Loss: 11.9850,  Validation Loss: 11.1384
# Epoch 7/100, Train_Loss: 12.5123,  Validation Loss: 9.8483
# Epoch 8/100, Train_Loss: 12.9408,  Validation Loss: 10.6137
# Epoch 9/100, Train_Loss: 11.7966,  Validation Loss: 10.3970
# Epoch 10/100, Train_Loss: 11.8344,  Validation Loss: 10.0058
# Epoch 11/100, Train_Loss: 11.9974,  Validation Loss: 9.8360
# Epoch 12/100, Train_Loss: 11.6673,  Validation Loss: 9.9490
# Epoch 13/100, Train_Loss: 12.2051,  Validation Loss: 10.0166
# Epoch 14/100, Train_Loss: 11.3546,  Validation Loss: 9.5278
# Epoch 15/100, Train_Loss: 12.0427,  Validation Loss: 9.5972
# Epoch 16/100, Train_Loss: 11.5913,  Validation Loss: 9.3651
# Epoch 17/100, Train_Loss: 11.8572,  Validation Loss: 9.7511
# Epoch 18/100, Train_Loss: 12.0225,  Validation Loss: 11.2292
# Epoch 19/100, Train_Loss: 12.0760,  Validation Loss: 11.1418
# Epoch 20/100, Train_Loss: 12.1051,  Validation Loss: 10.1395
# Epoch 21/100, Train_Loss: 11.6485,  Validation Loss: 10.1524
# Epoch 22/100, Train_Loss: 11.8996,  Validation Loss: 10.7883
# Epoch 23/100, Train_Loss: 11.4511,  Validation Loss: 11.7864
# Epoch 24/100, Train_Loss: 11.1705,  Validation Loss: 9.4596
# Epoch 25/100, Train_Loss: 11.6068,  Validation Loss: 10.6157
# Epoch 26/100, Train_Loss: 11.9031,  Validation Loss: 12.6250
# Epoch 27/100, Train_Loss: 11.6065,  Validation Loss: 8.8428
# Epoch 28/100, Train_Loss: 11.6307,  Validation Loss: 9.4028
# Epoch 29/100, Train_Loss: 11.7349,  Validation Loss: 9.1094
# Epoch 30/100, Train_Loss: 11.6629,  Validation Loss: 9.4829
# Epoch 31/100, Train_Loss: 11.3745,  Validation Loss: 9.5716
# Epoch 32/100, Train_Loss: 11.8717,  Validation Loss: 8.7954
# Epoch 33/100, Train_Loss: 12.5946,  Validation Loss: 9.9063
# Epoch 34/100, Train_Loss: 11.5330,  Validation Loss: 9.4377
# Epoch 35/100, Train_Loss: 11.5919,  Validation Loss: 9.3125
# Epoch 36/100, Train_Loss: 11.6239,  Validation Loss: 9.6348
# Epoch 37/100, Train_Loss: 11.5349,  Validation Loss: 9.3852
# Epoch 38/100, Train_Loss: 11.6857,  Validation Loss: 9.0690
# Epoch 39/100, Train_Loss: 12.2273,  Validation Loss: 9.0859
# Epoch 40/100, Train_Loss: 11.7970,  Validation Loss: 9.2429
# Epoch 41/100, Train_Loss: 11.9520,  Validation Loss: 9.0725
# Epoch 42/100, Train_Loss: 12.3422,  Validation Loss: 8.9963
# Epoch 43/100, Train_Loss: 11.7660,  Validation Loss: 9.9539
# Epoch 44/100, Train_Loss: 11.7076,  Validation Loss: 9.4210
# Epoch 45/100, Train_Loss: 11.3929,  Validation Loss: 10.7448
# Epoch 46/100, Train_Loss: 12.2778,  Validation Loss: 8.8609
# Epoch 47/100, Train_Loss: 12.3410,  Validation Loss: 8.9075
# Epoch 48/100, Train_Loss: 11.9589,  Validation Loss: 9.1840
# Epoch 49/100, Train_Loss: 11.6696,  Validation Loss: 9.4246
# Epoch 50/100, Train_Loss: 12.1655,  Validation Loss: 9.2556
# Epoch 51/100, Train_Loss: 11.6462,  Validation Loss: 9.1869
# Epoch 52/100, Train_Loss: 11.4339,  Validation Loss: 9.1737
# Epoch 53/100, Train_Loss: 11.7393,  Validation Loss: 10.1536
# Epoch 54/100, Train_Loss: 11.8701,  Validation Loss: 9.0991
# Epoch 55/100, Train_Loss: 11.9350,  Validation Loss: 10.4909
# Epoch 56/100, Train_Loss: 11.6403,  Validation Loss: 8.8675
# Epoch 57/100, Train_Loss: 12.2845,  Validation Loss: 9.5756
# Epoch 58/100, Train_Loss: 11.8108,  Validation Loss: 9.2286
# Epoch 59/100, Train_Loss: 11.5936,  Validation Loss: 9.6480
# Epoch 60/100, Train_Loss: 11.7672,  Validation Loss: 9.3820
# Epoch 61/100, Train_Loss: 11.3311,  Validation Loss: 10.0127
# Epoch 62/100, Train_Loss: 11.7386,  Validation Loss: 9.0421
# Epoch 63/100, Train_Loss: 12.1720,  Validation Loss: 8.9594
# Epoch 64/100, Train_Loss: 11.8127,  Validation Loss: 9.3996
# Epoch 65/100, Train_Loss: 11.6234,  Validation Loss: 9.2522
# Epoch 66/100, Train_Loss: 11.9055,  Validation Loss: 9.5825
# Epoch 67/100, Train_Loss: 11.5840,  Validation Loss: 9.2446
# Epoch 68/100, Train_Loss: 12.1563,  Validation Loss: 10.1294
# Epoch 69/100, Train_Loss: 11.5962,  Validation Loss: 8.9246
# Epoch 70/100, Train_Loss: 12.5271,  Validation Loss: 10.5917
# Epoch 71/100, Train_Loss: 12.0796,  Validation Loss: 9.3721
# Epoch 72/100, Train_Loss: 11.6297,  Validation Loss: 10.1599
# Epoch 73/100, Train_Loss: 12.1045,  Validation Loss: 11.0782
# Epoch 74/100, Train_Loss: 11.7707,  Validation Loss: 8.9539
# Epoch 75/100, Train_Loss: 11.3512,  Validation Loss: 9.1886
# Epoch 76/100, Train_Loss: 11.5102,  Validation Loss: 10.2706
# Epoch 77/100, Train_Loss: 11.7111,  Validation Loss: 9.6841
# Epoch 78/100, Train_Loss: 11.4343,  Validation Loss: 9.7321
# Epoch 79/100, Train_Loss: 11.4793,  Validation Loss: 10.3251
# Epoch 80/100, Train_Loss: 11.6164,  Validation Loss: 9.7054
# Epoch 81/100, Train_Loss: 11.8073,  Validation Loss: 9.4733
# Epoch 82/100, Train_Loss: 11.9618,  Validation Loss: 9.0311
# Epoch 83/100, Train_Loss: 11.8254,  Validation Loss: 9.1207
# Epoch 84/100, Train_Loss: 11.3374,  Validation Loss: 9.3684
# Epoch 85/100, Train_Loss: 11.3716,  Validation Loss: 9.5823
# Epoch 86/100, Train_Loss: 11.4291,  Validation Loss: 8.9823
# Epoch 87/100, Train_Loss: 11.1814,  Validation Loss: 9.2978
# Epoch 88/100, Train_Loss: 11.2910,  Validation Loss: 9.3729
# Epoch 89/100, Train_Loss: 11.3875,  Validation Loss: 9.9632
# Epoch 90/100, Train_Loss: 11.8617,  Validation Loss: 9.0465
# Epoch 91/100, Train_Loss: 11.4962,  Validation Loss: 11.3404
# Epoch 92/100, Train_Loss: 11.4309,  Validation Loss: 9.5456
# Epoch 93/100, Train_Loss: 11.9965,  Validation Loss: 9.7692
# Epoch 94/100, Train_Loss: 11.3615,  Validation Loss: 10.5044
# Epoch 95/100, Train_Loss: 11.9552,  Validation Loss: 9.7274
# Epoch 96/100, Train_Loss: 11.9062,  Validation Loss: 9.3789
# Epoch 97/100, Train_Loss: 11.6403,  Validation Loss: 10.5657
# Epoch 98/100, Train_Loss: 11.8605,  Validation Loss: 10.6653
# Epoch 99/100, Train_Loss: 12.2414,  Validation Loss: 9.5776
# Epoch 100/100, Train_Loss: 11.8378,  Validation Loss: 10.4262

# %%
plt.plot(train_losses, label='loss')
plt.plot(val_losses, label='val_loss')
# plt.ylim([0, 40])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()
plt.grid(True)

# %%
plt.plot(train_r2, label='r2')
plt.plot(val_r2, label='val_r2')
# plt.ylim([0, 40])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()
plt.grid(True)
