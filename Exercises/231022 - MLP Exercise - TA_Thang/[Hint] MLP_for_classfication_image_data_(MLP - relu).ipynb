# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /home/server-ailab-12gb/miniconda3/envs/Khoa_env/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# From (redirected): https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP&confirm=t&uuid=3972a87b-a353-405d-9375-a0500165b311
# To: /home/server-ailab-12gb/Khoa/AIO2023/hint/Final/sol/FER-2013.zip
# 100%|██████████████████████████████████████| 63.3M/63.3M [00:01<00:00, 41.7MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng tf.data

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Resize
from torchvision.io import read_image
import os
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)

# %%
batch_size = 256
img_height = 180
img_width = 180
image_count = 28709
train_dir = "/content/train"
val_dir = "/content/test"

# %%
class ImageDataset(Dataset):
    def __init__(self, img_dir, norm):
        self.resize = Resize((img_height, img_width))
        self.norm = norm
        self.img_dir = img_dir
        self.classes = os.listdir(img_dir)
        self.image_files = [(os.path.join(cls, img), cls) for cls in self.classes for img in os.listdir(os.path.join(img_dir, cls))]
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.idx_to_class = {idx:cls  for cls, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path, cls = self.image_files[idx]
        image = self.resize(read_image(os.path.join(self.img_dir, img_path)))
        image = image.type(torch.float32)
        label = self.class_to_idx[cls]
        if self.norm:
            image = (image/127.5) - 1
        return image, label

# %%
train_dataset = ImageDataset(train_dir, True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = ImageDataset(val_dir, True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
image_batch, label_batch = next(iter(train_loader))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(train_dataset.idx_to_class[label.item()])
  plt.axis("off")
# Out:
# /home/server-ailab-12gb/miniconda3/envs/Khoa_env/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# ##### MLP - tanh

# %%
######################### YOUR CODE HERE #########################
# Thiết kế model theo yêu cầu đề  bài 
# Hidden layer 1: Linear layer in_features = input_dims (180*180), out_features = hidden_dims*4 (1024),  
# activation = tanh
# Hidden layer 2: Linear layer in_features = hidden_dims*4 (1024), out_features = hidden_dims*2 (512), 
# activation = tanh
# Hidden layer 3: Linear layer in_features = hidden_dims*2 (512), out_features = hidden_dims (256), 
# activation = tanh
# Output layer: Linear layer in_features = hidden_dims (256), out_features = output_dims (7) 

class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):

    def forward(self, x):
##################################################################

model = MLP(input_dims=180*180, hidden_dims=256, output_dims=7).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.006)

# %%
num_epochs = 100
train_losses = []
train_acc = []
val_losses = []
val_acc = []
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    accuracy = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        accuracy += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    accuracy /= cnt
    train_acc.append(accuracy)


    model.eval()
    val_loss = 0.0
    val_accuracy = 0
    cnt = 0
    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)
            val_loss += loss.item()
            val_accuracy += (torch.argmax(outputs, 1) == y).sum().item()
            cnt += len(y)
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_accuracy /= cnt
    val_acc.append(val_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {train_loss:.4f},  Train_Acc: {accuracy:.4f}, Val_Loss: {val_loss:.4f},  Val_Acc: {val_accuracy:.4f}")
# Out:
# Epoch 1/100, Train_Loss: 1.8984,  Train_Acc: 0.2211, Val_Loss: 1.8571,  Val_Acc: 0.2485
# Epoch 2/100, Train_Loss: 1.8239,  Train_Acc: 0.2517, Val_Loss: 1.8044,  Val_Acc: 0.2512
# Epoch 3/100, Train_Loss: 1.7874,  Train_Acc: 0.2705, Val_Loss: 1.7796,  Val_Acc: 0.2757
# Epoch 4/100, Train_Loss: 1.7676,  Train_Acc: 0.2923, Val_Loss: 1.7602,  Val_Acc: 0.2988
# Epoch 5/100, Train_Loss: 1.7485,  Train_Acc: 0.3091, Val_Loss: 1.7414,  Val_Acc: 0.3090
# Epoch 6/100, Train_Loss: 1.7275,  Train_Acc: 0.3245, Val_Loss: 1.7175,  Val_Acc: 0.3335
# Epoch 7/100, Train_Loss: 1.7029,  Train_Acc: 0.3389, Val_Loss: 1.6926,  Val_Acc: 0.3456
# Epoch 8/100, Train_Loss: 1.6800,  Train_Acc: 0.3506, Val_Loss: 1.6705,  Val_Acc: 0.3518
# Epoch 9/100, Train_Loss: 1.6570,  Train_Acc: 0.3603, Val_Loss: 1.6571,  Val_Acc: 0.3553
# Epoch 10/100, Train_Loss: 1.6423,  Train_Acc: 0.3666, Val_Loss: 1.6412,  Val_Acc: 0.3704
# Epoch 11/100, Train_Loss: 1.6292,  Train_Acc: 0.3715, Val_Loss: 1.6315,  Val_Acc: 0.3753
# Epoch 12/100, Train_Loss: 1.6165,  Train_Acc: 0.3777, Val_Loss: 1.6196,  Val_Acc: 0.3784
# Epoch 13/100, Train_Loss: 1.6074,  Train_Acc: 0.3828, Val_Loss: 1.6165,  Val_Acc: 0.3834
# Epoch 14/100, Train_Loss: 1.5979,  Train_Acc: 0.3855, Val_Loss: 1.6146,  Val_Acc: 0.3809
# Epoch 15/100, Train_Loss: 1.5911,  Train_Acc: 0.3895, Val_Loss: 1.6151,  Val_Acc: 0.3787
# Epoch 16/100, Train_Loss: 1.5808,  Train_Acc: 0.3921, Val_Loss: 1.5973,  Val_Acc: 0.3885
# Epoch 17/100, Train_Loss: 1.5727,  Train_Acc: 0.3970, Val_Loss: 1.6042,  Val_Acc: 0.3853
# Epoch 18/100, Train_Loss: 1.5641,  Train_Acc: 0.3979, Val_Loss: 1.5879,  Val_Acc: 0.3958
# Epoch 19/100, Train_Loss: 1.5562,  Train_Acc: 0.4017, Val_Loss: 1.5836,  Val_Acc: 0.3963
# Epoch 20/100, Train_Loss: 1.5488,  Train_Acc: 0.4064, Val_Loss: 1.5743,  Val_Acc: 0.4019
# Epoch 21/100, Train_Loss: 1.5390,  Train_Acc: 0.4083, Val_Loss: 1.5683,  Val_Acc: 0.4051
# Epoch 22/100, Train_Loss: 1.5313,  Train_Acc: 0.4123, Val_Loss: 1.5628,  Val_Acc: 0.4036
# Epoch 23/100, Train_Loss: 1.5244,  Train_Acc: 0.4186, Val_Loss: 1.5594,  Val_Acc: 0.4028
# Epoch 24/100, Train_Loss: 1.5139,  Train_Acc: 0.4202, Val_Loss: 1.5738,  Val_Acc: 0.3975
# Epoch 25/100, Train_Loss: 1.5083,  Train_Acc: 0.4240, Val_Loss: 1.5681,  Val_Acc: 0.4009
# Epoch 26/100, Train_Loss: 1.4967,  Train_Acc: 0.4295, Val_Loss: 1.5525,  Val_Acc: 0.4100
# Epoch 27/100, Train_Loss: 1.4902,  Train_Acc: 0.4329, Val_Loss: 1.5492,  Val_Acc: 0.4101
# Epoch 28/100, Train_Loss: 1.4825,  Train_Acc: 0.4368, Val_Loss: 1.5693,  Val_Acc: 0.4023
# Epoch 29/100, Train_Loss: 1.4725,  Train_Acc: 0.4402, Val_Loss: 1.5537,  Val_Acc: 0.4039
# Epoch 30/100, Train_Loss: 1.4634,  Train_Acc: 0.4434, Val_Loss: 1.5370,  Val_Acc: 0.4122
# Epoch 31/100, Train_Loss: 1.4514,  Train_Acc: 0.4493, Val_Loss: 1.5467,  Val_Acc: 0.4108
# Epoch 32/100, Train_Loss: 1.4471,  Train_Acc: 0.4490, Val_Loss: 1.5710,  Val_Acc: 0.4003
# Epoch 33/100, Train_Loss: 1.4357,  Train_Acc: 0.4567, Val_Loss: 1.5289,  Val_Acc: 0.4181
# Epoch 34/100, Train_Loss: 1.4261,  Train_Acc: 0.4599, Val_Loss: 1.6083,  Val_Acc: 0.3899
# Epoch 35/100, Train_Loss: 1.4194,  Train_Acc: 0.4633, Val_Loss: 1.5319,  Val_Acc: 0.4239
# Epoch 36/100, Train_Loss: 1.4092,  Train_Acc: 0.4681, Val_Loss: 1.5180,  Val_Acc: 0.4225
# Epoch 37/100, Train_Loss: 1.4007,  Train_Acc: 0.4732, Val_Loss: 1.5245,  Val_Acc: 0.4216
# Epoch 38/100, Train_Loss: 1.3912,  Train_Acc: 0.4758, Val_Loss: 1.5293,  Val_Acc: 0.4159
# Epoch 39/100, Train_Loss: 1.3813,  Train_Acc: 0.4796, Val_Loss: 1.6004,  Val_Acc: 0.3957
# Epoch 40/100, Train_Loss: 1.3789,  Train_Acc: 0.4820, Val_Loss: 1.6102,  Val_Acc: 0.3923
# Epoch 41/100, Train_Loss: 1.3679,  Train_Acc: 0.4858, Val_Loss: 1.5327,  Val_Acc: 0.4157
# Epoch 42/100, Train_Loss: 1.3641,  Train_Acc: 0.4896, Val_Loss: 1.5407,  Val_Acc: 0.4139
# Epoch 43/100, Train_Loss: 1.3528,  Train_Acc: 0.4936, Val_Loss: 1.6036,  Val_Acc: 0.3930
# Epoch 44/100, Train_Loss: 1.3406,  Train_Acc: 0.4964, Val_Loss: 1.5813,  Val_Acc: 0.4030
# Epoch 45/100, Train_Loss: 1.3301,  Train_Acc: 0.5039, Val_Loss: 1.5664,  Val_Acc: 0.4083
# Epoch 46/100, Train_Loss: 1.3271,  Train_Acc: 0.5022, Val_Loss: 1.5177,  Val_Acc: 0.4171
# Epoch 47/100, Train_Loss: 1.3148,  Train_Acc: 0.5097, Val_Loss: 1.5450,  Val_Acc: 0.4189
# Epoch 48/100, Train_Loss: 1.3060,  Train_Acc: 0.5142, Val_Loss: 1.7168,  Val_Acc: 0.3760
# Epoch 49/100, Train_Loss: 1.2962,  Train_Acc: 0.5186, Val_Loss: 1.6872,  Val_Acc: 0.3908
# Epoch 50/100, Train_Loss: 1.2907,  Train_Acc: 0.5198, Val_Loss: 2.0234,  Val_Acc: 0.3566
# Epoch 51/100, Train_Loss: 1.2868,  Train_Acc: 0.5243, Val_Loss: 1.5540,  Val_Acc: 0.4164
# Epoch 52/100, Train_Loss: 1.2717,  Train_Acc: 0.5292, Val_Loss: 1.5910,  Val_Acc: 0.4111
# Epoch 53/100, Train_Loss: 1.2615,  Train_Acc: 0.5316, Val_Loss: 1.6371,  Val_Acc: 0.4090
# Epoch 54/100, Train_Loss: 1.2458,  Train_Acc: 0.5387, Val_Loss: 1.5434,  Val_Acc: 0.4263
# Epoch 55/100, Train_Loss: 1.2357,  Train_Acc: 0.5431, Val_Loss: 1.5779,  Val_Acc: 0.4023
# Epoch 56/100, Train_Loss: 1.2358,  Train_Acc: 0.5436, Val_Loss: 1.5595,  Val_Acc: 0.4252
# Epoch 57/100, Train_Loss: 1.2172,  Train_Acc: 0.5541, Val_Loss: 1.6136,  Val_Acc: 0.4167
# Epoch 58/100, Train_Loss: 1.2080,  Train_Acc: 0.5566, Val_Loss: 1.7278,  Val_Acc: 0.3885
# Epoch 59/100, Train_Loss: 1.1990,  Train_Acc: 0.5612, Val_Loss: 1.5272,  Val_Acc: 0.4302
# Epoch 60/100, Train_Loss: 1.1829,  Train_Acc: 0.5691, Val_Loss: 1.6072,  Val_Acc: 0.4113
# Epoch 61/100, Train_Loss: 1.1748,  Train_Acc: 0.5690, Val_Loss: 1.5873,  Val_Acc: 0.4225
# Epoch 62/100, Train_Loss: 1.1651,  Train_Acc: 0.5725, Val_Loss: 1.6961,  Val_Acc: 0.4096
# Epoch 63/100, Train_Loss: 1.1611,  Train_Acc: 0.5750, Val_Loss: 1.7751,  Val_Acc: 0.4093
# Epoch 64/100, Train_Loss: 1.1494,  Train_Acc: 0.5810, Val_Loss: 1.7616,  Val_Acc: 0.3820
# Epoch 65/100, Train_Loss: 1.1366,  Train_Acc: 0.5880, Val_Loss: 1.6125,  Val_Acc: 0.4121
# Epoch 66/100, Train_Loss: 1.1309,  Train_Acc: 0.5903, Val_Loss: 1.7076,  Val_Acc: 0.4050
# Epoch 67/100, Train_Loss: 1.1153,  Train_Acc: 0.5949, Val_Loss: 1.6595,  Val_Acc: 0.4147
# Epoch 68/100, Train_Loss: 1.1173,  Train_Acc: 0.5967, Val_Loss: 1.9883,  Val_Acc: 0.3576
# Epoch 69/100, Train_Loss: 1.0952,  Train_Acc: 0.6055, Val_Loss: 1.9134,  Val_Acc: 0.3654
# Epoch 70/100, Train_Loss: 1.0837,  Train_Acc: 0.6103, Val_Loss: 1.9009,  Val_Acc: 0.3582
# Epoch 71/100, Train_Loss: 1.0762,  Train_Acc: 0.6143, Val_Loss: 1.8571,  Val_Acc: 0.3837
# Epoch 72/100, Train_Loss: 1.0654,  Train_Acc: 0.6197, Val_Loss: 1.9779,  Val_Acc: 0.3784
# Epoch 73/100, Train_Loss: 1.0592,  Train_Acc: 0.6197, Val_Loss: 1.7867,  Val_Acc: 0.3644
# Epoch 74/100, Train_Loss: 1.0367,  Train_Acc: 0.6291, Val_Loss: 1.9010,  Val_Acc: 0.3633
# Epoch 75/100, Train_Loss: 1.0350,  Train_Acc: 0.6335, Val_Loss: 2.1762,  Val_Acc: 0.3683
# Epoch 76/100, Train_Loss: 1.0265,  Train_Acc: 0.6322, Val_Loss: 1.7839,  Val_Acc: 0.3922
# Epoch 77/100, Train_Loss: 1.0256,  Train_Acc: 0.6353, Val_Loss: 1.6561,  Val_Acc: 0.4179
# Epoch 78/100, Train_Loss: 0.9906,  Train_Acc: 0.6494, Val_Loss: 1.8266,  Val_Acc: 0.4115
# Epoch 79/100, Train_Loss: 0.9998,  Train_Acc: 0.6441, Val_Loss: 1.9446,  Val_Acc: 0.3636
# Epoch 80/100, Train_Loss: 0.9799,  Train_Acc: 0.6519, Val_Loss: 2.0878,  Val_Acc: 0.3522
# Epoch 81/100, Train_Loss: 0.9575,  Train_Acc: 0.6635, Val_Loss: 1.8777,  Val_Acc: 0.4118
# Epoch 82/100, Train_Loss: 0.9594,  Train_Acc: 0.6635, Val_Loss: 1.8996,  Val_Acc: 0.3943
# Epoch 83/100, Train_Loss: 0.9533,  Train_Acc: 0.6671, Val_Loss: 1.8028,  Val_Acc: 0.4302
# Epoch 84/100, Train_Loss: 0.9459,  Train_Acc: 0.6663, Val_Loss: 1.9254,  Val_Acc: 0.3838
# Epoch 85/100, Train_Loss: 0.9084,  Train_Acc: 0.6905, Val_Loss: 2.0761,  Val_Acc: 0.3954
# Epoch 86/100, Train_Loss: 0.9136,  Train_Acc: 0.6802, Val_Loss: 1.8390,  Val_Acc: 0.4030
# Epoch 87/100, Train_Loss: 0.8908,  Train_Acc: 0.6909, Val_Loss: 1.8810,  Val_Acc: 0.4133
# Epoch 88/100, Train_Loss: 0.8938,  Train_Acc: 0.6914, Val_Loss: 1.8267,  Val_Acc: 0.4315
# Epoch 89/100, Train_Loss: 0.8742,  Train_Acc: 0.6974, Val_Loss: 2.8301,  Val_Acc: 0.3151
# Epoch 90/100, Train_Loss: 0.8771,  Train_Acc: 0.6983, Val_Loss: 1.9117,  Val_Acc: 0.4103
# Epoch 91/100, Train_Loss: 0.8541,  Train_Acc: 0.7087, Val_Loss: 1.9404,  Val_Acc: 0.3968
# Epoch 92/100, Train_Loss: 0.8349,  Train_Acc: 0.7108, Val_Loss: 2.1041,  Val_Acc: 0.4157
# Epoch 93/100, Train_Loss: 0.8284,  Train_Acc: 0.7205, Val_Loss: 1.9435,  Val_Acc: 0.4023
# Epoch 94/100, Train_Loss: 0.8192,  Train_Acc: 0.7209, Val_Loss: 1.7921,  Val_Acc: 0.4172
# Epoch 95/100, Train_Loss: 0.8054,  Train_Acc: 0.7266, Val_Loss: 1.9374,  Val_Acc: 0.4182
# Epoch 96/100, Train_Loss: 0.8053,  Train_Acc: 0.7295, Val_Loss: 2.3111,  Val_Acc: 0.3739
# Epoch 97/100, Train_Loss: 0.7932,  Train_Acc: 0.7354, Val_Loss: 2.1049,  Val_Acc: 0.3858
# Epoch 98/100, Train_Loss: 0.7807,  Train_Acc: 0.7353, Val_Loss: 2.1583,  Val_Acc: 0.3689
# Epoch 99/100, Train_Loss: 0.7649,  Train_Acc: 0.7421, Val_Loss: 1.9229,  Val_Acc: 0.4150
# Epoch 100/100, Train_Loss: 0.7503,  Train_Acc: 0.7479, Val_Loss: 2.6482,  Val_Acc: 0.3442

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(train_losses, label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(train_acc, label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(val_losses, label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(val_acc, label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)
