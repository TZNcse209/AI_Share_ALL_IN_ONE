# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bUBWn2Osoc6Y1XskxF_o0JgWVFw0iV_6
# Out:
# /home/server-ailab-12gb/miniconda3/envs/Khoa_env/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1bUBWn2Osoc6Y1XskxF_o0JgWVFw0iV_6
# To: /home/server-ailab-12gb/Khoa/AIO2023/hint/Final/sol/NonLinear_data.npy
# 100%|██████████████████████████████████████| 5.57k/5.57k [00:00<00:00, 1.67MB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)

# %% [markdown]
# ## Load Data

# %%
data_path = "/content/NonLinear_data.npy"
data = np.load(data_path, allow_pickle=True).item()
X, labels = data["X"], data["labels"].astype(int)
# X, labels = torch.tensor(X, dtype=torch.float32), torch.tensor(labels, dtype=torch.long)
X, labels = torch.tensor(X, dtype=torch.float32), torch.tensor(labels)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        # print(idx)
        return self.X[idx], self.y[idx]

# %%
train_dataset = CustomDataset(X, labels)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# ## Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %% [markdown]
# ### MLP - relu

# %%
######################### YOUR CODE HERE #########################
# Thiết kế model theo yêu cầu đề  bài 
# Hidden layer 1: Linear layer in_features = input_dims (2), out_features = hidden_dims (128),  
# activation = relu
# Output layer: Linear layer in_features = hidden_dims (128), out_features = output_dims (3), 
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):

    def forward(self, x):
##################################################################

model = MLP(input_dims=2, hidden_dims=128, output_dims=3).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
num_epochs = 500
train_losses = []
train_acc = []

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    accuracy = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        accuracy += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    accuracy /= cnt
    train_acc.append(accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {train_loss:.4f},  Train_Acc: {accuracy:.4f}")
# Out:
# Epoch 1/500, Train_Loss: 1.0046,  Train_Acc: 0.4967
# Epoch 2/500, Train_Loss: 0.8844,  Train_Acc: 0.5433
# Epoch 3/500, Train_Loss: 0.8256,  Train_Acc: 0.5767
# Epoch 4/500, Train_Loss: 0.7872,  Train_Acc: 0.5467
# Epoch 5/500, Train_Loss: 0.7652,  Train_Acc: 0.5467
# Epoch 6/500, Train_Loss: 0.7519,  Train_Acc: 0.5433
# Epoch 7/500, Train_Loss: 0.7434,  Train_Acc: 0.5467
# Epoch 8/500, Train_Loss: 0.7412,  Train_Acc: 0.5600
# Epoch 9/500, Train_Loss: 0.7449,  Train_Acc: 0.5767
# Epoch 10/500, Train_Loss: 0.7341,  Train_Acc: 0.5767
# Epoch 11/500, Train_Loss: 0.7457,  Train_Acc: 0.5633
# Epoch 12/500, Train_Loss: 0.6956,  Train_Acc: 0.5700
# Epoch 13/500, Train_Loss: 0.7165,  Train_Acc: 0.5533
# Epoch 14/500, Train_Loss: 0.7034,  Train_Acc: 0.5633
# Epoch 15/500, Train_Loss: 0.6965,  Train_Acc: 0.5700
# Epoch 16/500, Train_Loss: 0.7091,  Train_Acc: 0.5767
# Epoch 17/500, Train_Loss: 0.7062,  Train_Acc: 0.5633
# Epoch 18/500, Train_Loss: 0.6927,  Train_Acc: 0.5700
# Epoch 19/500, Train_Loss: 0.6868,  Train_Acc: 0.5833
# Epoch 20/500, Train_Loss: 0.6776,  Train_Acc: 0.5900
# Epoch 21/500, Train_Loss: 0.6769,  Train_Acc: 0.5900
# Epoch 22/500, Train_Loss: 0.6628,  Train_Acc: 0.6000
# Epoch 23/500, Train_Loss: 0.6577,  Train_Acc: 0.5867
# Epoch 24/500, Train_Loss: 0.6700,  Train_Acc: 0.5933
# Epoch 25/500, Train_Loss: 0.6628,  Train_Acc: 0.6033
# Epoch 26/500, Train_Loss: 0.6530,  Train_Acc: 0.5967
# Epoch 27/500, Train_Loss: 0.6537,  Train_Acc: 0.6200
# Epoch 28/500, Train_Loss: 0.6289,  Train_Acc: 0.6067
# Epoch 29/500, Train_Loss: 0.6312,  Train_Acc: 0.6133
# Epoch 30/500, Train_Loss: 0.6325,  Train_Acc: 0.6133
# Epoch 31/500, Train_Loss: 0.6394,  Train_Acc: 0.6467
# Epoch 32/500, Train_Loss: 0.6321,  Train_Acc: 0.6333
# Epoch 33/500, Train_Loss: 0.6279,  Train_Acc: 0.6367
# Epoch 34/500, Train_Loss: 0.6234,  Train_Acc: 0.6200
# Epoch 35/500, Train_Loss: 0.6048,  Train_Acc: 0.6467
# Epoch 36/500, Train_Loss: 0.5968,  Train_Acc: 0.6533
# Epoch 37/500, Train_Loss: 0.6029,  Train_Acc: 0.6500
# Epoch 38/500, Train_Loss: 0.6024,  Train_Acc: 0.6600
# Epoch 39/500, Train_Loss: 0.5888,  Train_Acc: 0.6533
# Epoch 40/500, Train_Loss: 0.5821,  Train_Acc: 0.6533
# Epoch 41/500, Train_Loss: 0.5917,  Train_Acc: 0.6800
# Epoch 42/500, Train_Loss: 0.5952,  Train_Acc: 0.6533
# Epoch 43/500, Train_Loss: 0.5904,  Train_Acc: 0.6667
# Epoch 44/500, Train_Loss: 0.5642,  Train_Acc: 0.6567
# Epoch 45/500, Train_Loss: 0.5691,  Train_Acc: 0.6633
# Epoch 46/500, Train_Loss: 0.5683,  Train_Acc: 0.6900
# Epoch 47/500, Train_Loss: 0.5612,  Train_Acc: 0.6833
# Epoch 48/500, Train_Loss: 0.5538,  Train_Acc: 0.6733
# Epoch 49/500, Train_Loss: 0.5432,  Train_Acc: 0.6633
# Epoch 50/500, Train_Loss: 0.5498,  Train_Acc: 0.7067
# Epoch 51/500, Train_Loss: 0.5427,  Train_Acc: 0.7000
# Epoch 52/500, Train_Loss: 0.5366,  Train_Acc: 0.6900
# Epoch 53/500, Train_Loss: 0.5290,  Train_Acc: 0.7033
# Epoch 54/500, Train_Loss: 0.5253,  Train_Acc: 0.6800
# Epoch 55/500, Train_Loss: 0.5236,  Train_Acc: 0.6900
# Epoch 56/500, Train_Loss: 0.5309,  Train_Acc: 0.7133
# Epoch 57/500, Train_Loss: 0.5366,  Train_Acc: 0.7200
# Epoch 58/500, Train_Loss: 0.5128,  Train_Acc: 0.7133
# Epoch 59/500, Train_Loss: 0.5045,  Train_Acc: 0.7067
# Epoch 60/500, Train_Loss: 0.5072,  Train_Acc: 0.7200
# Epoch 61/500, Train_Loss: 0.5026,  Train_Acc: 0.7267
# Epoch 62/500, Train_Loss: 0.5063,  Train_Acc: 0.7233
# Epoch 63/500, Train_Loss: 0.4804,  Train_Acc: 0.7267
# Epoch 64/500, Train_Loss: 0.5069,  Train_Acc: 0.7367
# Epoch 65/500, Train_Loss: 0.4727,  Train_Acc: 0.7633
# Epoch 66/500, Train_Loss: 0.4792,  Train_Acc: 0.7567
# Epoch 67/500, Train_Loss: 0.4636,  Train_Acc: 0.7467
# Epoch 68/500, Train_Loss: 0.4734,  Train_Acc: 0.7567
# Epoch 69/500, Train_Loss: 0.4739,  Train_Acc: 0.7500
# Epoch 70/500, Train_Loss: 0.4631,  Train_Acc: 0.7667
# Epoch 71/500, Train_Loss: 0.4699,  Train_Acc: 0.7733
# Epoch 72/500, Train_Loss: 0.4522,  Train_Acc: 0.7600
# Epoch 73/500, Train_Loss: 0.4522,  Train_Acc: 0.7667
# Epoch 74/500, Train_Loss: 0.4554,  Train_Acc: 0.7633
# Epoch 75/500, Train_Loss: 0.4485,  Train_Acc: 0.7733
# Epoch 76/500, Train_Loss: 0.4546,  Train_Acc: 0.8100
# Epoch 77/500, Train_Loss: 0.4560,  Train_Acc: 0.7967
# Epoch 78/500, Train_Loss: 0.4451,  Train_Acc: 0.8000
# Epoch 79/500, Train_Loss: 0.4385,  Train_Acc: 0.7900
# Epoch 80/500, Train_Loss: 0.4317,  Train_Acc: 0.7967
# Epoch 81/500, Train_Loss: 0.4256,  Train_Acc: 0.7833
# Epoch 82/500, Train_Loss: 0.4212,  Train_Acc: 0.7933
# Epoch 83/500, Train_Loss: 0.4208,  Train_Acc: 0.8033
# Epoch 84/500, Train_Loss: 0.4251,  Train_Acc: 0.8033
# Epoch 85/500, Train_Loss: 0.4234,  Train_Acc: 0.8000
# Epoch 86/500, Train_Loss: 0.4059,  Train_Acc: 0.8200
# Epoch 87/500, Train_Loss: 0.4046,  Train_Acc: 0.8133
# Epoch 88/500, Train_Loss: 0.4045,  Train_Acc: 0.8067
# Epoch 89/500, Train_Loss: 0.4085,  Train_Acc: 0.8167
# Epoch 90/500, Train_Loss: 0.3981,  Train_Acc: 0.8100
# Epoch 91/500, Train_Loss: 0.3902,  Train_Acc: 0.8333
# Epoch 92/500, Train_Loss: 0.3880,  Train_Acc: 0.8200
# Epoch 93/500, Train_Loss: 0.3933,  Train_Acc: 0.8233
# Epoch 94/500, Train_Loss: 0.3857,  Train_Acc: 0.8300
# Epoch 95/500, Train_Loss: 0.3912,  Train_Acc: 0.8100
# Epoch 96/500, Train_Loss: 0.3927,  Train_Acc: 0.8133
# Epoch 97/500, Train_Loss: 0.3732,  Train_Acc: 0.8400
# Epoch 98/500, Train_Loss: 0.3692,  Train_Acc: 0.8133
# Epoch 99/500, Train_Loss: 0.3781,  Train_Acc: 0.8233
# Epoch 100/500, Train_Loss: 0.3552,  Train_Acc: 0.8333
# Epoch 101/500, Train_Loss: 0.3722,  Train_Acc: 0.8267
# Epoch 102/500, Train_Loss: 0.3726,  Train_Acc: 0.8400
# Epoch 103/500, Train_Loss: 0.3659,  Train_Acc: 0.8533
# Epoch 104/500, Train_Loss: 0.3556,  Train_Acc: 0.8333
# Epoch 105/500, Train_Loss: 0.3562,  Train_Acc: 0.8633
# Epoch 106/500, Train_Loss: 0.3580,  Train_Acc: 0.8367
# Epoch 107/500, Train_Loss: 0.3546,  Train_Acc: 0.8400
# Epoch 108/500, Train_Loss: 0.3600,  Train_Acc: 0.8467
# Epoch 109/500, Train_Loss: 0.3555,  Train_Acc: 0.8367
# Epoch 110/500, Train_Loss: 0.3556,  Train_Acc: 0.8467
# Epoch 111/500, Train_Loss: 0.3478,  Train_Acc: 0.8667
# Epoch 112/500, Train_Loss: 0.3495,  Train_Acc: 0.8367
# Epoch 113/500, Train_Loss: 0.3297,  Train_Acc: 0.8700
# Epoch 114/500, Train_Loss: 0.3367,  Train_Acc: 0.8367
# Epoch 115/500, Train_Loss: 0.3376,  Train_Acc: 0.8700
# Epoch 116/500, Train_Loss: 0.3374,  Train_Acc: 0.8333
# Epoch 117/500, Train_Loss: 0.3463,  Train_Acc: 0.8367
# Epoch 118/500, Train_Loss: 0.3363,  Train_Acc: 0.8533
# Epoch 119/500, Train_Loss: 0.3355,  Train_Acc: 0.8400
# Epoch 120/500, Train_Loss: 0.3288,  Train_Acc: 0.8667
# Epoch 121/500, Train_Loss: 0.3144,  Train_Acc: 0.8633
# Epoch 122/500, Train_Loss: 0.3182,  Train_Acc: 0.8600
# Epoch 123/500, Train_Loss: 0.3289,  Train_Acc: 0.8567
# Epoch 124/500, Train_Loss: 0.3259,  Train_Acc: 0.8533
# Epoch 125/500, Train_Loss: 0.3274,  Train_Acc: 0.8700
# Epoch 126/500, Train_Loss: 0.3236,  Train_Acc: 0.8733
# Epoch 127/500, Train_Loss: 0.3096,  Train_Acc: 0.8667
# Epoch 128/500, Train_Loss: 0.3087,  Train_Acc: 0.8833
# Epoch 129/500, Train_Loss: 0.3208,  Train_Acc: 0.8833
# Epoch 130/500, Train_Loss: 0.2951,  Train_Acc: 0.8733
# Epoch 131/500, Train_Loss: 0.3115,  Train_Acc: 0.8667
# Epoch 132/500, Train_Loss: 0.3068,  Train_Acc: 0.8667
# Epoch 133/500, Train_Loss: 0.3080,  Train_Acc: 0.8767
# Epoch 134/500, Train_Loss: 0.3089,  Train_Acc: 0.8667
# Epoch 135/500, Train_Loss: 0.2935,  Train_Acc: 0.8800
# Epoch 136/500, Train_Loss: 0.3005,  Train_Acc: 0.8767
# Epoch 137/500, Train_Loss: 0.2918,  Train_Acc: 0.8700
# Epoch 138/500, Train_Loss: 0.2986,  Train_Acc: 0.8933
# Epoch 139/500, Train_Loss: 0.2937,  Train_Acc: 0.8667
# Epoch 140/500, Train_Loss: 0.2825,  Train_Acc: 0.8800
# Epoch 141/500, Train_Loss: 0.2936,  Train_Acc: 0.8667
# Epoch 142/500, Train_Loss: 0.2917,  Train_Acc: 0.8767
# Epoch 143/500, Train_Loss: 0.2907,  Train_Acc: 0.8667
# Epoch 144/500, Train_Loss: 0.2931,  Train_Acc: 0.8667
# Epoch 145/500, Train_Loss: 0.2778,  Train_Acc: 0.8833
# Epoch 146/500, Train_Loss: 0.2798,  Train_Acc: 0.8833
# Epoch 147/500, Train_Loss: 0.2836,  Train_Acc: 0.8933
# Epoch 148/500, Train_Loss: 0.2878,  Train_Acc: 0.8733
# Epoch 149/500, Train_Loss: 0.2781,  Train_Acc: 0.8867
# Epoch 150/500, Train_Loss: 0.2816,  Train_Acc: 0.8733
# Epoch 151/500, Train_Loss: 0.2735,  Train_Acc: 0.9000
# Epoch 152/500, Train_Loss: 0.2796,  Train_Acc: 0.8800
# Epoch 153/500, Train_Loss: 0.2898,  Train_Acc: 0.8967
# Epoch 154/500, Train_Loss: 0.2727,  Train_Acc: 0.8933
# Epoch 155/500, Train_Loss: 0.2753,  Train_Acc: 0.8967
# Epoch 156/500, Train_Loss: 0.2646,  Train_Acc: 0.8933
# Epoch 157/500, Train_Loss: 0.2588,  Train_Acc: 0.9000
# Epoch 158/500, Train_Loss: 0.2656,  Train_Acc: 0.8833
# Epoch 159/500, Train_Loss: 0.2649,  Train_Acc: 0.8967
# Epoch 160/500, Train_Loss: 0.2592,  Train_Acc: 0.9067
# Epoch 161/500, Train_Loss: 0.2538,  Train_Acc: 0.8833
# Epoch 162/500, Train_Loss: 0.2658,  Train_Acc: 0.8900
# Epoch 163/500, Train_Loss: 0.2673,  Train_Acc: 0.8900
# Epoch 164/500, Train_Loss: 0.2660,  Train_Acc: 0.8967
# Epoch 165/500, Train_Loss: 0.2537,  Train_Acc: 0.8967
# Epoch 166/500, Train_Loss: 0.2676,  Train_Acc: 0.8900
# Epoch 167/500, Train_Loss: 0.2633,  Train_Acc: 0.8933
# Epoch 168/500, Train_Loss: 0.2509,  Train_Acc: 0.8967
# Epoch 169/500, Train_Loss: 0.2457,  Train_Acc: 0.9033
# Epoch 170/500, Train_Loss: 0.2510,  Train_Acc: 0.9033
# Epoch 171/500, Train_Loss: 0.2468,  Train_Acc: 0.9067
# Epoch 172/500, Train_Loss: 0.2537,  Train_Acc: 0.9000
# Epoch 173/500, Train_Loss: 0.2469,  Train_Acc: 0.9000
# Epoch 174/500, Train_Loss: 0.2443,  Train_Acc: 0.9067
# Epoch 175/500, Train_Loss: 0.2393,  Train_Acc: 0.9067
# Epoch 176/500, Train_Loss: 0.2460,  Train_Acc: 0.9000
# Epoch 177/500, Train_Loss: 0.2354,  Train_Acc: 0.9000
# Epoch 178/500, Train_Loss: 0.2480,  Train_Acc: 0.8967
# Epoch 179/500, Train_Loss: 0.2443,  Train_Acc: 0.9100
# Epoch 180/500, Train_Loss: 0.2498,  Train_Acc: 0.9000
# Epoch 181/500, Train_Loss: 0.2487,  Train_Acc: 0.9100
# Epoch 182/500, Train_Loss: 0.2445,  Train_Acc: 0.9067
# Epoch 183/500, Train_Loss: 0.2386,  Train_Acc: 0.9267
# Epoch 184/500, Train_Loss: 0.2413,  Train_Acc: 0.9033
# Epoch 185/500, Train_Loss: 0.2509,  Train_Acc: 0.8933
# Epoch 186/500, Train_Loss: 0.2354,  Train_Acc: 0.9033
# Epoch 187/500, Train_Loss: 0.2374,  Train_Acc: 0.9067
# Epoch 188/500, Train_Loss: 0.2416,  Train_Acc: 0.9100
# Epoch 189/500, Train_Loss: 0.2400,  Train_Acc: 0.9067
# Epoch 190/500, Train_Loss: 0.2202,  Train_Acc: 0.9067
# Epoch 191/500, Train_Loss: 0.2281,  Train_Acc: 0.9033
# Epoch 192/500, Train_Loss: 0.2215,  Train_Acc: 0.9100
# Epoch 193/500, Train_Loss: 0.2320,  Train_Acc: 0.9100
# Epoch 194/500, Train_Loss: 0.2357,  Train_Acc: 0.9067
# Epoch 195/500, Train_Loss: 0.2187,  Train_Acc: 0.9067
# Epoch 196/500, Train_Loss: 0.2300,  Train_Acc: 0.9100
# Epoch 197/500, Train_Loss: 0.2185,  Train_Acc: 0.9167
# Epoch 198/500, Train_Loss: 0.2293,  Train_Acc: 0.9033
# Epoch 199/500, Train_Loss: 0.2281,  Train_Acc: 0.9133
# Epoch 200/500, Train_Loss: 0.2251,  Train_Acc: 0.9100
# Epoch 201/500, Train_Loss: 0.2130,  Train_Acc: 0.9000
# Epoch 202/500, Train_Loss: 0.2230,  Train_Acc: 0.9133
# Epoch 203/500, Train_Loss: 0.2200,  Train_Acc: 0.9167
# Epoch 204/500, Train_Loss: 0.2205,  Train_Acc: 0.9267
# Epoch 205/500, Train_Loss: 0.2207,  Train_Acc: 0.9167
# Epoch 206/500, Train_Loss: 0.2295,  Train_Acc: 0.9133
# Epoch 207/500, Train_Loss: 0.2163,  Train_Acc: 0.9200
# Epoch 208/500, Train_Loss: 0.2114,  Train_Acc: 0.9100
# Epoch 209/500, Train_Loss: 0.2137,  Train_Acc: 0.9300
# Epoch 210/500, Train_Loss: 0.2105,  Train_Acc: 0.9267
# Epoch 211/500, Train_Loss: 0.2170,  Train_Acc: 0.9167
# Epoch 212/500, Train_Loss: 0.2144,  Train_Acc: 0.9233
# Epoch 213/500, Train_Loss: 0.2259,  Train_Acc: 0.9200
# Epoch 214/500, Train_Loss: 0.2021,  Train_Acc: 0.9067
# Epoch 215/500, Train_Loss: 0.2078,  Train_Acc: 0.9000
# Epoch 216/500, Train_Loss: 0.2220,  Train_Acc: 0.9200
# Epoch 217/500, Train_Loss: 0.2072,  Train_Acc: 0.9133
# Epoch 218/500, Train_Loss: 0.2031,  Train_Acc: 0.9200
# Epoch 219/500, Train_Loss: 0.2104,  Train_Acc: 0.9200
# Epoch 220/500, Train_Loss: 0.2059,  Train_Acc: 0.9267
# Epoch 221/500, Train_Loss: 0.2093,  Train_Acc: 0.8967
# Epoch 222/500, Train_Loss: 0.2019,  Train_Acc: 0.9267
# Epoch 223/500, Train_Loss: 0.2053,  Train_Acc: 0.9233
# Epoch 224/500, Train_Loss: 0.1970,  Train_Acc: 0.9233
# Epoch 225/500, Train_Loss: 0.1965,  Train_Acc: 0.9300
# Epoch 226/500, Train_Loss: 0.1991,  Train_Acc: 0.9233
# Epoch 227/500, Train_Loss: 0.2023,  Train_Acc: 0.9167
# Epoch 228/500, Train_Loss: 0.2031,  Train_Acc: 0.9267
# Epoch 229/500, Train_Loss: 0.1986,  Train_Acc: 0.9200
# Epoch 230/500, Train_Loss: 0.2095,  Train_Acc: 0.9333
# Epoch 231/500, Train_Loss: 0.1980,  Train_Acc: 0.9200
# Epoch 232/500, Train_Loss: 0.2013,  Train_Acc: 0.9100
# Epoch 233/500, Train_Loss: 0.2020,  Train_Acc: 0.9233
# Epoch 234/500, Train_Loss: 0.1916,  Train_Acc: 0.9267
# Epoch 235/500, Train_Loss: 0.2029,  Train_Acc: 0.9100
# Epoch 236/500, Train_Loss: 0.2011,  Train_Acc: 0.9333
# Epoch 237/500, Train_Loss: 0.1885,  Train_Acc: 0.9133
# Epoch 238/500, Train_Loss: 0.1876,  Train_Acc: 0.9433
# Epoch 239/500, Train_Loss: 0.2018,  Train_Acc: 0.9267
# Epoch 240/500, Train_Loss: 0.1946,  Train_Acc: 0.9267
# Epoch 241/500, Train_Loss: 0.1979,  Train_Acc: 0.9100
# Epoch 242/500, Train_Loss: 0.1880,  Train_Acc: 0.9300
# Epoch 243/500, Train_Loss: 0.1904,  Train_Acc: 0.9233
# Epoch 244/500, Train_Loss: 0.1945,  Train_Acc: 0.9300
# Epoch 245/500, Train_Loss: 0.1887,  Train_Acc: 0.9267
# Epoch 246/500, Train_Loss: 0.1860,  Train_Acc: 0.9200
# Epoch 247/500, Train_Loss: 0.1827,  Train_Acc: 0.9333
# Epoch 248/500, Train_Loss: 0.1872,  Train_Acc: 0.9333
# Epoch 249/500, Train_Loss: 0.1924,  Train_Acc: 0.9333
# Epoch 250/500, Train_Loss: 0.1893,  Train_Acc: 0.9300
# Epoch 251/500, Train_Loss: 0.1899,  Train_Acc: 0.9100
# Epoch 252/500, Train_Loss: 0.1851,  Train_Acc: 0.9333
# Epoch 253/500, Train_Loss: 0.1791,  Train_Acc: 0.9367
# Epoch 254/500, Train_Loss: 0.1869,  Train_Acc: 0.9367
# Epoch 255/500, Train_Loss: 0.1873,  Train_Acc: 0.9400
# Epoch 256/500, Train_Loss: 0.1816,  Train_Acc: 0.9300
# Epoch 257/500, Train_Loss: 0.1873,  Train_Acc: 0.9300
# Epoch 258/500, Train_Loss: 0.1748,  Train_Acc: 0.9300
# Epoch 259/500, Train_Loss: 0.1818,  Train_Acc: 0.9333
# Epoch 260/500, Train_Loss: 0.1809,  Train_Acc: 0.9200
# Epoch 261/500, Train_Loss: 0.1765,  Train_Acc: 0.9233
# Epoch 262/500, Train_Loss: 0.1820,  Train_Acc: 0.9333
# Epoch 263/500, Train_Loss: 0.1740,  Train_Acc: 0.9300
# Epoch 264/500, Train_Loss: 0.1887,  Train_Acc: 0.9400
# Epoch 265/500, Train_Loss: 0.1771,  Train_Acc: 0.9300
# Epoch 266/500, Train_Loss: 0.1838,  Train_Acc: 0.9300
# Epoch 267/500, Train_Loss: 0.1693,  Train_Acc: 0.9333
# Epoch 268/500, Train_Loss: 0.1839,  Train_Acc: 0.9400
# Epoch 269/500, Train_Loss: 0.1848,  Train_Acc: 0.9300
# Epoch 270/500, Train_Loss: 0.1798,  Train_Acc: 0.9267
# Epoch 271/500, Train_Loss: 0.1715,  Train_Acc: 0.9267
# Epoch 272/500, Train_Loss: 0.1741,  Train_Acc: 0.9367
# Epoch 273/500, Train_Loss: 0.1675,  Train_Acc: 0.9333
# Epoch 274/500, Train_Loss: 0.1680,  Train_Acc: 0.9333
# Epoch 275/500, Train_Loss: 0.1746,  Train_Acc: 0.9367
# Epoch 276/500, Train_Loss: 0.1675,  Train_Acc: 0.9367
# Epoch 277/500, Train_Loss: 0.1695,  Train_Acc: 0.9267
# Epoch 278/500, Train_Loss: 0.1748,  Train_Acc: 0.9300
# Epoch 279/500, Train_Loss: 0.1631,  Train_Acc: 0.9300
# Epoch 280/500, Train_Loss: 0.1690,  Train_Acc: 0.9400
# Epoch 281/500, Train_Loss: 0.1698,  Train_Acc: 0.9300
# Epoch 282/500, Train_Loss: 0.1645,  Train_Acc: 0.9400
# Epoch 283/500, Train_Loss: 0.1677,  Train_Acc: 0.9367
# Epoch 284/500, Train_Loss: 0.1610,  Train_Acc: 0.9267
# Epoch 285/500, Train_Loss: 0.1668,  Train_Acc: 0.9400
# Epoch 286/500, Train_Loss: 0.1688,  Train_Acc: 0.9400
# Epoch 287/500, Train_Loss: 0.1684,  Train_Acc: 0.9267
# Epoch 288/500, Train_Loss: 0.1604,  Train_Acc: 0.9333
# Epoch 289/500, Train_Loss: 0.1575,  Train_Acc: 0.9433
# Epoch 290/500, Train_Loss: 0.1693,  Train_Acc: 0.9367
# Epoch 291/500, Train_Loss: 0.1680,  Train_Acc: 0.9367
# Epoch 292/500, Train_Loss: 0.1599,  Train_Acc: 0.9500
# Epoch 293/500, Train_Loss: 0.1675,  Train_Acc: 0.9367
# Epoch 294/500, Train_Loss: 0.1665,  Train_Acc: 0.9433
# Epoch 295/500, Train_Loss: 0.1603,  Train_Acc: 0.9367
# Epoch 296/500, Train_Loss: 0.1661,  Train_Acc: 0.9333
# Epoch 297/500, Train_Loss: 0.1637,  Train_Acc: 0.9433
# Epoch 298/500, Train_Loss: 0.1586,  Train_Acc: 0.9367
# Epoch 299/500, Train_Loss: 0.1625,  Train_Acc: 0.9433
# Epoch 300/500, Train_Loss: 0.1599,  Train_Acc: 0.9367
# Epoch 301/500, Train_Loss: 0.1635,  Train_Acc: 0.9500
# Epoch 302/500, Train_Loss: 0.1555,  Train_Acc: 0.9333
# Epoch 303/500, Train_Loss: 0.1535,  Train_Acc: 0.9400
# Epoch 304/500, Train_Loss: 0.1663,  Train_Acc: 0.9367
# Epoch 305/500, Train_Loss: 0.1577,  Train_Acc: 0.9367
# Epoch 306/500, Train_Loss: 0.1655,  Train_Acc: 0.9300
# Epoch 307/500, Train_Loss: 0.1651,  Train_Acc: 0.9400
# Epoch 308/500, Train_Loss: 0.1495,  Train_Acc: 0.9533
# Epoch 309/500, Train_Loss: 0.1644,  Train_Acc: 0.9500
# Epoch 310/500, Train_Loss: 0.1556,  Train_Acc: 0.9400
# Epoch 311/500, Train_Loss: 0.1573,  Train_Acc: 0.9433
# Epoch 312/500, Train_Loss: 0.1535,  Train_Acc: 0.9467
# Epoch 313/500, Train_Loss: 0.1588,  Train_Acc: 0.9433
# Epoch 314/500, Train_Loss: 0.1531,  Train_Acc: 0.9367
# Epoch 315/500, Train_Loss: 0.1567,  Train_Acc: 0.9467
# Epoch 316/500, Train_Loss: 0.1500,  Train_Acc: 0.9433
# Epoch 317/500, Train_Loss: 0.1685,  Train_Acc: 0.9433
# Epoch 318/500, Train_Loss: 0.1560,  Train_Acc: 0.9400
# Epoch 319/500, Train_Loss: 0.1499,  Train_Acc: 0.9433
# Epoch 320/500, Train_Loss: 0.1528,  Train_Acc: 0.9500
# Epoch 321/500, Train_Loss: 0.1560,  Train_Acc: 0.9400
# Epoch 322/500, Train_Loss: 0.1573,  Train_Acc: 0.9500
# Epoch 323/500, Train_Loss: 0.1549,  Train_Acc: 0.9433
# Epoch 324/500, Train_Loss: 0.1526,  Train_Acc: 0.9467
# Epoch 325/500, Train_Loss: 0.1547,  Train_Acc: 0.9467
# Epoch 326/500, Train_Loss: 0.1521,  Train_Acc: 0.9433
# Epoch 327/500, Train_Loss: 0.1487,  Train_Acc: 0.9467
# Epoch 328/500, Train_Loss: 0.1534,  Train_Acc: 0.9400
# Epoch 329/500, Train_Loss: 0.1419,  Train_Acc: 0.9333
# Epoch 330/500, Train_Loss: 0.1428,  Train_Acc: 0.9533
# Epoch 331/500, Train_Loss: 0.1581,  Train_Acc: 0.9433
# Epoch 332/500, Train_Loss: 0.1522,  Train_Acc: 0.9500
# Epoch 333/500, Train_Loss: 0.1619,  Train_Acc: 0.9500
# Epoch 334/500, Train_Loss: 0.1596,  Train_Acc: 0.9333
# Epoch 335/500, Train_Loss: 0.1448,  Train_Acc: 0.9567
# Epoch 336/500, Train_Loss: 0.1479,  Train_Acc: 0.9500
# Epoch 337/500, Train_Loss: 0.1468,  Train_Acc: 0.9333
# Epoch 338/500, Train_Loss: 0.1522,  Train_Acc: 0.9467
# Epoch 339/500, Train_Loss: 0.1418,  Train_Acc: 0.9533
# Epoch 340/500, Train_Loss: 0.1515,  Train_Acc: 0.9567
# Epoch 341/500, Train_Loss: 0.1440,  Train_Acc: 0.9467
# Epoch 342/500, Train_Loss: 0.1483,  Train_Acc: 0.9500
# Epoch 343/500, Train_Loss: 0.1366,  Train_Acc: 0.9600
# Epoch 344/500, Train_Loss: 0.1405,  Train_Acc: 0.9600
# Epoch 345/500, Train_Loss: 0.1381,  Train_Acc: 0.9467
# Epoch 346/500, Train_Loss: 0.1479,  Train_Acc: 0.9533
# Epoch 347/500, Train_Loss: 0.1349,  Train_Acc: 0.9500
# Epoch 348/500, Train_Loss: 0.1436,  Train_Acc: 0.9500
# Epoch 349/500, Train_Loss: 0.1445,  Train_Acc: 0.9633
# Epoch 350/500, Train_Loss: 0.1497,  Train_Acc: 0.9500
# Epoch 351/500, Train_Loss: 0.1611,  Train_Acc: 0.9333
# Epoch 352/500, Train_Loss: 0.1443,  Train_Acc: 0.9433
# Epoch 353/500, Train_Loss: 0.1376,  Train_Acc: 0.9500
# Epoch 354/500, Train_Loss: 0.1492,  Train_Acc: 0.9433
# Epoch 355/500, Train_Loss: 0.1480,  Train_Acc: 0.9467
# Epoch 356/500, Train_Loss: 0.1337,  Train_Acc: 0.9600
# Epoch 357/500, Train_Loss: 0.1350,  Train_Acc: 0.9433
# Epoch 358/500, Train_Loss: 0.1368,  Train_Acc: 0.9567
# Epoch 359/500, Train_Loss: 0.1386,  Train_Acc: 0.9433
# Epoch 360/500, Train_Loss: 0.1398,  Train_Acc: 0.9500
# Epoch 361/500, Train_Loss: 0.1413,  Train_Acc: 0.9567
# Epoch 362/500, Train_Loss: 0.1346,  Train_Acc: 0.9533
# Epoch 363/500, Train_Loss: 0.1360,  Train_Acc: 0.9400
# Epoch 364/500, Train_Loss: 0.1413,  Train_Acc: 0.9533
# Epoch 365/500, Train_Loss: 0.1395,  Train_Acc: 0.9567
# Epoch 366/500, Train_Loss: 0.1459,  Train_Acc: 0.9600
# Epoch 367/500, Train_Loss: 0.1455,  Train_Acc: 0.9567
# Epoch 368/500, Train_Loss: 0.1321,  Train_Acc: 0.9533
# Epoch 369/500, Train_Loss: 0.1352,  Train_Acc: 0.9567
# Epoch 370/500, Train_Loss: 0.1309,  Train_Acc: 0.9567
# Epoch 371/500, Train_Loss: 0.1328,  Train_Acc: 0.9633
# Epoch 372/500, Train_Loss: 0.1425,  Train_Acc: 0.9467
# Epoch 373/500, Train_Loss: 0.1290,  Train_Acc: 0.9533
# Epoch 374/500, Train_Loss: 0.1352,  Train_Acc: 0.9433
# Epoch 375/500, Train_Loss: 0.1444,  Train_Acc: 0.9533
# Epoch 376/500, Train_Loss: 0.1302,  Train_Acc: 0.9500
# Epoch 377/500, Train_Loss: 0.1317,  Train_Acc: 0.9633
# Epoch 378/500, Train_Loss: 0.1381,  Train_Acc: 0.9500
# Epoch 379/500, Train_Loss: 0.1407,  Train_Acc: 0.9567
# Epoch 380/500, Train_Loss: 0.1460,  Train_Acc: 0.9567
# Epoch 381/500, Train_Loss: 0.1416,  Train_Acc: 0.9467
# Epoch 382/500, Train_Loss: 0.1332,  Train_Acc: 0.9633
# Epoch 383/500, Train_Loss: 0.1403,  Train_Acc: 0.9600
# Epoch 384/500, Train_Loss: 0.1317,  Train_Acc: 0.9600
# Epoch 385/500, Train_Loss: 0.1255,  Train_Acc: 0.9600
# Epoch 386/500, Train_Loss: 0.1269,  Train_Acc: 0.9533
# Epoch 387/500, Train_Loss: 0.1300,  Train_Acc: 0.9567
# Epoch 388/500, Train_Loss: 0.1296,  Train_Acc: 0.9600
# Epoch 389/500, Train_Loss: 0.1277,  Train_Acc: 0.9600
# Epoch 390/500, Train_Loss: 0.1503,  Train_Acc: 0.9567
# Epoch 391/500, Train_Loss: 0.1336,  Train_Acc: 0.9533
# Epoch 392/500, Train_Loss: 0.1327,  Train_Acc: 0.9567
# Epoch 393/500, Train_Loss: 0.1259,  Train_Acc: 0.9600
# Epoch 394/500, Train_Loss: 0.1339,  Train_Acc: 0.9567
# Epoch 395/500, Train_Loss: 0.1280,  Train_Acc: 0.9567
# Epoch 396/500, Train_Loss: 0.1266,  Train_Acc: 0.9567
# Epoch 397/500, Train_Loss: 0.1284,  Train_Acc: 0.9600
# Epoch 398/500, Train_Loss: 0.1249,  Train_Acc: 0.9567
# Epoch 399/500, Train_Loss: 0.1306,  Train_Acc: 0.9533
# Epoch 400/500, Train_Loss: 0.1242,  Train_Acc: 0.9633
# Epoch 401/500, Train_Loss: 0.1307,  Train_Acc: 0.9600
# Epoch 402/500, Train_Loss: 0.1309,  Train_Acc: 0.9533
# Epoch 403/500, Train_Loss: 0.1334,  Train_Acc: 0.9567
# Epoch 404/500, Train_Loss: 0.1230,  Train_Acc: 0.9500
# Epoch 405/500, Train_Loss: 0.1262,  Train_Acc: 0.9700
# Epoch 406/500, Train_Loss: 0.1286,  Train_Acc: 0.9567
# Epoch 407/500, Train_Loss: 0.1329,  Train_Acc: 0.9633
# Epoch 408/500, Train_Loss: 0.1261,  Train_Acc: 0.9600
# Epoch 409/500, Train_Loss: 0.1232,  Train_Acc: 0.9633
# Epoch 410/500, Train_Loss: 0.1292,  Train_Acc: 0.9633
# Epoch 411/500, Train_Loss: 0.1234,  Train_Acc: 0.9600
# Epoch 412/500, Train_Loss: 0.1269,  Train_Acc: 0.9700
# Epoch 413/500, Train_Loss: 0.1331,  Train_Acc: 0.9667
# Epoch 414/500, Train_Loss: 0.1188,  Train_Acc: 0.9667
# Epoch 415/500, Train_Loss: 0.1261,  Train_Acc: 0.9633
# Epoch 416/500, Train_Loss: 0.1388,  Train_Acc: 0.9567
# Epoch 417/500, Train_Loss: 0.1239,  Train_Acc: 0.9700
# Epoch 418/500, Train_Loss: 0.1183,  Train_Acc: 0.9667
# Epoch 419/500, Train_Loss: 0.1230,  Train_Acc: 0.9667
# Epoch 420/500, Train_Loss: 0.1217,  Train_Acc: 0.9633
# Epoch 421/500, Train_Loss: 0.1200,  Train_Acc: 0.9667
# Epoch 422/500, Train_Loss: 0.1174,  Train_Acc: 0.9633
# Epoch 423/500, Train_Loss: 0.1332,  Train_Acc: 0.9667
# Epoch 424/500, Train_Loss: 0.1245,  Train_Acc: 0.9600
# Epoch 425/500, Train_Loss: 0.1215,  Train_Acc: 0.9567
# Epoch 426/500, Train_Loss: 0.1176,  Train_Acc: 0.9633
# Epoch 427/500, Train_Loss: 0.1203,  Train_Acc: 0.9600
# Epoch 428/500, Train_Loss: 0.1234,  Train_Acc: 0.9600
# Epoch 429/500, Train_Loss: 0.1271,  Train_Acc: 0.9667
# Epoch 430/500, Train_Loss: 0.1152,  Train_Acc: 0.9700
# Epoch 431/500, Train_Loss: 0.1200,  Train_Acc: 0.9667
# Epoch 432/500, Train_Loss: 0.1160,  Train_Acc: 0.9633
# Epoch 433/500, Train_Loss: 0.1207,  Train_Acc: 0.9700
# Epoch 434/500, Train_Loss: 0.1162,  Train_Acc: 0.9700
# Epoch 435/500, Train_Loss: 0.1148,  Train_Acc: 0.9633
# Epoch 436/500, Train_Loss: 0.1228,  Train_Acc: 0.9667
# Epoch 437/500, Train_Loss: 0.1151,  Train_Acc: 0.9700
# Epoch 438/500, Train_Loss: 0.1131,  Train_Acc: 0.9733
# Epoch 439/500, Train_Loss: 0.1188,  Train_Acc: 0.9733
# Epoch 440/500, Train_Loss: 0.1284,  Train_Acc: 0.9700
# Epoch 441/500, Train_Loss: 0.1124,  Train_Acc: 0.9600
# Epoch 442/500, Train_Loss: 0.1122,  Train_Acc: 0.9733
# Epoch 443/500, Train_Loss: 0.1179,  Train_Acc: 0.9733
# Epoch 444/500, Train_Loss: 0.1259,  Train_Acc: 0.9667
# Epoch 445/500, Train_Loss: 0.1159,  Train_Acc: 0.9667
# Epoch 446/500, Train_Loss: 0.1129,  Train_Acc: 0.9667
# Epoch 447/500, Train_Loss: 0.1183,  Train_Acc: 0.9667
# Epoch 448/500, Train_Loss: 0.1124,  Train_Acc: 0.9733
# Epoch 449/500, Train_Loss: 0.1258,  Train_Acc: 0.9667
# Epoch 450/500, Train_Loss: 0.1162,  Train_Acc: 0.9667
# Epoch 451/500, Train_Loss: 0.1143,  Train_Acc: 0.9600
# Epoch 452/500, Train_Loss: 0.1149,  Train_Acc: 0.9700
# Epoch 453/500, Train_Loss: 0.1101,  Train_Acc: 0.9767
# Epoch 454/500, Train_Loss: 0.1128,  Train_Acc: 0.9700
# Epoch 455/500, Train_Loss: 0.1160,  Train_Acc: 0.9733
# Epoch 456/500, Train_Loss: 0.1104,  Train_Acc: 0.9700
# Epoch 457/500, Train_Loss: 0.1108,  Train_Acc: 0.9600
# Epoch 458/500, Train_Loss: 0.1136,  Train_Acc: 0.9633
# Epoch 459/500, Train_Loss: 0.1270,  Train_Acc: 0.9667
# Epoch 460/500, Train_Loss: 0.1151,  Train_Acc: 0.9533
# Epoch 461/500, Train_Loss: 0.1090,  Train_Acc: 0.9667
# Epoch 462/500, Train_Loss: 0.1218,  Train_Acc: 0.9633
# Epoch 463/500, Train_Loss: 0.1200,  Train_Acc: 0.9633
# Epoch 464/500, Train_Loss: 0.1096,  Train_Acc: 0.9700
# Epoch 465/500, Train_Loss: 0.1098,  Train_Acc: 0.9667
# Epoch 466/500, Train_Loss: 0.1153,  Train_Acc: 0.9633
# Epoch 467/500, Train_Loss: 0.1210,  Train_Acc: 0.9633
# Epoch 468/500, Train_Loss: 0.1097,  Train_Acc: 0.9667
# Epoch 469/500, Train_Loss: 0.1086,  Train_Acc: 0.9767
# Epoch 470/500, Train_Loss: 0.1071,  Train_Acc: 0.9767
# Epoch 471/500, Train_Loss: 0.1197,  Train_Acc: 0.9667
# Epoch 472/500, Train_Loss: 0.1175,  Train_Acc: 0.9567
# Epoch 473/500, Train_Loss: 0.1156,  Train_Acc: 0.9733
# Epoch 474/500, Train_Loss: 0.1200,  Train_Acc: 0.9667
# Epoch 475/500, Train_Loss: 0.1067,  Train_Acc: 0.9700
# Epoch 476/500, Train_Loss: 0.1155,  Train_Acc: 0.9700
# Epoch 477/500, Train_Loss: 0.1162,  Train_Acc: 0.9533
# Epoch 478/500, Train_Loss: 0.1190,  Train_Acc: 0.9633
# Epoch 479/500, Train_Loss: 0.1087,  Train_Acc: 0.9633
# Epoch 480/500, Train_Loss: 0.1111,  Train_Acc: 0.9700
# Epoch 481/500, Train_Loss: 0.1119,  Train_Acc: 0.9667
# Epoch 482/500, Train_Loss: 0.1056,  Train_Acc: 0.9700
# Epoch 483/500, Train_Loss: 0.1101,  Train_Acc: 0.9767
# Epoch 484/500, Train_Loss: 0.1239,  Train_Acc: 0.9633
# Epoch 485/500, Train_Loss: 0.1127,  Train_Acc: 0.9767
# Epoch 486/500, Train_Loss: 0.1133,  Train_Acc: 0.9633
# Epoch 487/500, Train_Loss: 0.1036,  Train_Acc: 0.9700
# Epoch 488/500, Train_Loss: 0.1181,  Train_Acc: 0.9733
# Epoch 489/500, Train_Loss: 0.1201,  Train_Acc: 0.9733
# Epoch 490/500, Train_Loss: 0.1121,  Train_Acc: 0.9667
# Epoch 491/500, Train_Loss: 0.1035,  Train_Acc: 0.9667
# Epoch 492/500, Train_Loss: 0.1160,  Train_Acc: 0.9767
# Epoch 493/500, Train_Loss: 0.1024,  Train_Acc: 0.9700
# Epoch 494/500, Train_Loss: 0.1135,  Train_Acc: 0.9733
# Epoch 495/500, Train_Loss: 0.1118,  Train_Acc: 0.9700
# Epoch 496/500, Train_Loss: 0.1148,  Train_Acc: 0.9767
# Epoch 497/500, Train_Loss: 0.1047,  Train_Acc: 0.9667
# Epoch 498/500, Train_Loss: 0.1135,  Train_Acc: 0.9733
# Epoch 499/500, Train_Loss: 0.1128,  Train_Acc: 0.9767
# Epoch 500/500, Train_Loss: 0.1013,  Train_Acc: 0.9767

# %%
fig = plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)
