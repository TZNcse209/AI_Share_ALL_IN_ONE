# %% [markdown]
# ## Download data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /home/server-ailab-12gb/miniconda3/envs/Khoa_env/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# From (redirected): https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP&confirm=t&uuid=140f3ccb-e191-42b9-9b6d-9566760b3c60
# To: /home/server-ailab-12gb/Khoa/AIO2023/hint/Final/sol/FER-2013.zip
# 100%|██████████████████████████████████████| 63.3M/63.3M [00:01<00:00, 40.4MB/s]

# %% [markdown]
# ## Giải nén data

# %%
# !unzip -q "/content/FER-2013.zip"

# %% [markdown]
# ## Load và xử lý data dạng ảnh

# %% [markdown]
# ### Cách xử lý data dùng tf.data

# %% [markdown]
# #### Sử dụng Tensorflow để  build, compile và train và evaluate model. Kết quả train và evaluation được thể hiện bằng hình ảnh bằng cách sử dụng matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Resize
from torchvision.io import read_image
import os
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)

# %%
batch_size = 256
img_height = 180
img_width = 180
image_count = 28709
train_dir = "/content/train"
val_dir = "/content/test"

# %%
class ImageDataset(Dataset):
    def __init__(self, img_dir, norm):
        self.resize = Resize((img_height, img_width))
        self.norm = norm
        self.img_dir = img_dir
        self.classes = os.listdir(img_dir)
        self.image_files = [(os.path.join(cls, img), cls) for cls in self.classes for img in os.listdir(os.path.join(img_dir, cls))]
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.idx_to_class = {idx:cls  for cls, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path, cls = self.image_files[idx]
        image = self.resize(read_image(os.path.join(self.img_dir, img_path)))
        image = image.type(torch.float32)
        label = self.class_to_idx[cls]
        if self.norm:
            image = (image/127.5) - 1
        return image, label

# %%
train_dataset = ImageDataset(train_dir, True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = ImageDataset(val_dir, True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
image_batch, label_batch = next(iter(train_loader))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(train_dataset.idx_to_class[label.item()])
  plt.axis("off")
# Out:
# /home/server-ailab-12gb/miniconda3/envs/Khoa_env/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# ##### MLP - tanh

# %%
######################### YOUR CODE HERE #########################
# Thiết kế model theo yêu cầu đề  bài 
# Hidden layer 1: Linear layer in_features = input_dims (180*180), out_features = hidden_dims*4 (1024),  
# activation = relu
# Hidden layer 2: Linear layer in_features = hidden_dims*4 (1024), out_features = hidden_dims*2 (512), 
# activation = relu
# Hidden layer 3: Linear layer in_features = hidden_dims*2 (512), out_features = hidden_dims (256), 
# activation = relu
# Output layer: Linear layer in_features = hidden_dims (256), out_features = output_dims (7) 

class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):

    def forward(self, x):
##################################################################

model = MLP(input_dims=180*180, hidden_dims=256, output_dims=7).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.006)

# %%
num_epochs = 100
train_losses = []
train_acc = []
val_losses = []
val_acc = []
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    accuracy = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        accuracy += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    accuracy /= cnt
    train_acc.append(accuracy)


    model.eval()
    val_loss = 0.0
    val_accuracy = 0
    cnt = 0
    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)
            val_loss += loss.item()
            val_accuracy += (torch.argmax(outputs, 1) == y).sum().item()
            cnt += len(y)
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_accuracy /= cnt
    val_acc.append(val_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {train_loss:.4f},  Train_Acc: {accuracy:.4f}, Val_Loss: {val_loss:.4f},  Val_Acc: {val_accuracy:.4f}")
# Out:
# Epoch 1/100, Train_Loss: 1.8417,  Train_Acc: 0.2609, Val_Loss: 1.7974,  Val_Acc: 0.2863
# Epoch 2/100, Train_Loss: 1.7729,  Train_Acc: 0.2991, Val_Loss: 1.7489,  Val_Acc: 0.3186
# Epoch 3/100, Train_Loss: 1.7314,  Train_Acc: 0.3274, Val_Loss: 1.7198,  Val_Acc: 0.3332
# Epoch 4/100, Train_Loss: 1.7024,  Train_Acc: 0.3424, Val_Loss: 1.6910,  Val_Acc: 0.3557
# Epoch 5/100, Train_Loss: 1.6831,  Train_Acc: 0.3518, Val_Loss: 1.6786,  Val_Acc: 0.3610
# Epoch 6/100, Train_Loss: 1.6691,  Train_Acc: 0.3573, Val_Loss: 1.6680,  Val_Acc: 0.3658
# Epoch 7/100, Train_Loss: 1.6586,  Train_Acc: 0.3621, Val_Loss: 1.6598,  Val_Acc: 0.3731
# Epoch 8/100, Train_Loss: 1.6512,  Train_Acc: 0.3639, Val_Loss: 1.6537,  Val_Acc: 0.3748
# Epoch 9/100, Train_Loss: 1.6425,  Train_Acc: 0.3692, Val_Loss: 1.6578,  Val_Acc: 0.3625
# Epoch 10/100, Train_Loss: 1.6380,  Train_Acc: 0.3705, Val_Loss: 1.6471,  Val_Acc: 0.3689
# Epoch 11/100, Train_Loss: 1.6321,  Train_Acc: 0.3714, Val_Loss: 1.6409,  Val_Acc: 0.3766
# Epoch 12/100, Train_Loss: 1.6251,  Train_Acc: 0.3752, Val_Loss: 1.6341,  Val_Acc: 0.3796
# Epoch 13/100, Train_Loss: 1.6199,  Train_Acc: 0.3783, Val_Loss: 1.6355,  Val_Acc: 0.3760
# Epoch 14/100, Train_Loss: 1.6153,  Train_Acc: 0.3801, Val_Loss: 1.6545,  Val_Acc: 0.3625
# Epoch 15/100, Train_Loss: 1.6128,  Train_Acc: 0.3817, Val_Loss: 1.6488,  Val_Acc: 0.3671
# Epoch 16/100, Train_Loss: 1.6064,  Train_Acc: 0.3827, Val_Loss: 1.6333,  Val_Acc: 0.3718
# Epoch 17/100, Train_Loss: 1.6022,  Train_Acc: 0.3863, Val_Loss: 1.6350,  Val_Acc: 0.3706
# Epoch 18/100, Train_Loss: 1.5977,  Train_Acc: 0.3855, Val_Loss: 1.6328,  Val_Acc: 0.3710
# Epoch 19/100, Train_Loss: 1.5942,  Train_Acc: 0.3864, Val_Loss: 1.6243,  Val_Acc: 0.3787
# Epoch 20/100, Train_Loss: 1.5912,  Train_Acc: 0.3885, Val_Loss: 1.6191,  Val_Acc: 0.3846
# Epoch 21/100, Train_Loss: 1.5852,  Train_Acc: 0.3917, Val_Loss: 1.6138,  Val_Acc: 0.3849
# Epoch 22/100, Train_Loss: 1.5823,  Train_Acc: 0.3923, Val_Loss: 1.6128,  Val_Acc: 0.3809
# Epoch 23/100, Train_Loss: 1.5798,  Train_Acc: 0.3950, Val_Loss: 1.6130,  Val_Acc: 0.3851
# Epoch 24/100, Train_Loss: 1.5738,  Train_Acc: 0.3958, Val_Loss: 1.6212,  Val_Acc: 0.3761
# Epoch 25/100, Train_Loss: 1.5733,  Train_Acc: 0.3986, Val_Loss: 1.6148,  Val_Acc: 0.3806
# Epoch 26/100, Train_Loss: 1.5664,  Train_Acc: 0.4007, Val_Loss: 1.6111,  Val_Acc: 0.3828
# Epoch 27/100, Train_Loss: 1.5644,  Train_Acc: 0.4021, Val_Loss: 1.6086,  Val_Acc: 0.3858
# Epoch 28/100, Train_Loss: 1.5619,  Train_Acc: 0.4025, Val_Loss: 1.6299,  Val_Acc: 0.3764
# Epoch 29/100, Train_Loss: 1.5570,  Train_Acc: 0.4050, Val_Loss: 1.6131,  Val_Acc: 0.3778
# Epoch 30/100, Train_Loss: 1.5534,  Train_Acc: 0.4065, Val_Loss: 1.6019,  Val_Acc: 0.3906
# Epoch 31/100, Train_Loss: 1.5461,  Train_Acc: 0.4089, Val_Loss: 1.6127,  Val_Acc: 0.3867
# Epoch 32/100, Train_Loss: 1.5471,  Train_Acc: 0.4097, Val_Loss: 1.6271,  Val_Acc: 0.3748
# Epoch 33/100, Train_Loss: 1.5401,  Train_Acc: 0.4128, Val_Loss: 1.5969,  Val_Acc: 0.3933
# Epoch 34/100, Train_Loss: 1.5377,  Train_Acc: 0.4130, Val_Loss: 1.6479,  Val_Acc: 0.3682
# Epoch 35/100, Train_Loss: 1.5343,  Train_Acc: 0.4164, Val_Loss: 1.6074,  Val_Acc: 0.3902
# Epoch 36/100, Train_Loss: 1.5300,  Train_Acc: 0.4189, Val_Loss: 1.5953,  Val_Acc: 0.3940
# Epoch 37/100, Train_Loss: 1.5254,  Train_Acc: 0.4185, Val_Loss: 1.5983,  Val_Acc: 0.3951
# Epoch 38/100, Train_Loss: 1.5203,  Train_Acc: 0.4225, Val_Loss: 1.6016,  Val_Acc: 0.3890
# Epoch 39/100, Train_Loss: 1.5164,  Train_Acc: 0.4223, Val_Loss: 1.5897,  Val_Acc: 0.3916
# Epoch 40/100, Train_Loss: 1.5114,  Train_Acc: 0.4252, Val_Loss: 1.6116,  Val_Acc: 0.3727
# Epoch 41/100, Train_Loss: 1.5072,  Train_Acc: 0.4268, Val_Loss: 1.6050,  Val_Acc: 0.3837
# Epoch 42/100, Train_Loss: 1.5031,  Train_Acc: 0.4302, Val_Loss: 1.5922,  Val_Acc: 0.3912
# Epoch 43/100, Train_Loss: 1.4985,  Train_Acc: 0.4304, Val_Loss: 1.6010,  Val_Acc: 0.3898
# Epoch 44/100, Train_Loss: 1.4927,  Train_Acc: 0.4343, Val_Loss: 1.6020,  Val_Acc: 0.3789
# Epoch 45/100, Train_Loss: 1.4857,  Train_Acc: 0.4358, Val_Loss: 1.5906,  Val_Acc: 0.3862
# Epoch 46/100, Train_Loss: 1.4788,  Train_Acc: 0.4364, Val_Loss: 1.5963,  Val_Acc: 0.3794
# Epoch 47/100, Train_Loss: 1.4759,  Train_Acc: 0.4411, Val_Loss: 1.5926,  Val_Acc: 0.3904
# Epoch 48/100, Train_Loss: 1.4693,  Train_Acc: 0.4443, Val_Loss: 1.5991,  Val_Acc: 0.3827
# Epoch 49/100, Train_Loss: 1.4609,  Train_Acc: 0.4495, Val_Loss: 1.5908,  Val_Acc: 0.3911
# Epoch 50/100, Train_Loss: 1.4551,  Train_Acc: 0.4511, Val_Loss: 1.6199,  Val_Acc: 0.3724
# Epoch 51/100, Train_Loss: 1.4503,  Train_Acc: 0.4525, Val_Loss: 1.5866,  Val_Acc: 0.3873
# Epoch 52/100, Train_Loss: 1.4408,  Train_Acc: 0.4553, Val_Loss: 1.6037,  Val_Acc: 0.3828
# Epoch 53/100, Train_Loss: 1.4339,  Train_Acc: 0.4591, Val_Loss: 1.5910,  Val_Acc: 0.3862
# Epoch 54/100, Train_Loss: 1.4264,  Train_Acc: 0.4647, Val_Loss: 1.5829,  Val_Acc: 0.3859
# Epoch 55/100, Train_Loss: 1.4195,  Train_Acc: 0.4649, Val_Loss: 1.6103,  Val_Acc: 0.3813
# Epoch 56/100, Train_Loss: 1.4154,  Train_Acc: 0.4701, Val_Loss: 1.5597,  Val_Acc: 0.3969
# Epoch 57/100, Train_Loss: 1.4045,  Train_Acc: 0.4748, Val_Loss: 1.6657,  Val_Acc: 0.3766
# Epoch 58/100, Train_Loss: 1.3951,  Train_Acc: 0.4770, Val_Loss: 1.6321,  Val_Acc: 0.3791
# Epoch 59/100, Train_Loss: 1.3877,  Train_Acc: 0.4801, Val_Loss: 1.5738,  Val_Acc: 0.3938
# Epoch 60/100, Train_Loss: 1.3807,  Train_Acc: 0.4857, Val_Loss: 1.5783,  Val_Acc: 0.3998
# Epoch 61/100, Train_Loss: 1.3704,  Train_Acc: 0.4875, Val_Loss: 1.5642,  Val_Acc: 0.4012
# Epoch 62/100, Train_Loss: 1.3669,  Train_Acc: 0.4894, Val_Loss: 1.5822,  Val_Acc: 0.3945
# Epoch 63/100, Train_Loss: 1.3642,  Train_Acc: 0.4902, Val_Loss: 1.6422,  Val_Acc: 0.3856
# Epoch 64/100, Train_Loss: 1.3445,  Train_Acc: 0.5002, Val_Loss: 1.6189,  Val_Acc: 0.3890
# Epoch 65/100, Train_Loss: 1.3347,  Train_Acc: 0.5055, Val_Loss: 1.5721,  Val_Acc: 0.4008
# Epoch 66/100, Train_Loss: 1.3336,  Train_Acc: 0.5050, Val_Loss: 1.6110,  Val_Acc: 0.3927
# Epoch 67/100, Train_Loss: 1.3210,  Train_Acc: 0.5125, Val_Loss: 1.5923,  Val_Acc: 0.4055
# Epoch 68/100, Train_Loss: 1.3097,  Train_Acc: 0.5188, Val_Loss: 1.6483,  Val_Acc: 0.3858
# Epoch 69/100, Train_Loss: 1.2969,  Train_Acc: 0.5210, Val_Loss: 1.5949,  Val_Acc: 0.4025
# Epoch 70/100, Train_Loss: 1.2888,  Train_Acc: 0.5231, Val_Loss: 1.7804,  Val_Acc: 0.3512
# Epoch 71/100, Train_Loss: 1.2780,  Train_Acc: 0.5323, Val_Loss: 1.6898,  Val_Acc: 0.3821
# Epoch 72/100, Train_Loss: 1.2667,  Train_Acc: 0.5357, Val_Loss: 1.7037,  Val_Acc: 0.3802
# Epoch 73/100, Train_Loss: 1.2532,  Train_Acc: 0.5379, Val_Loss: 1.5944,  Val_Acc: 0.3961
# Epoch 74/100, Train_Loss: 1.2426,  Train_Acc: 0.5451, Val_Loss: 1.6240,  Val_Acc: 0.3973
# Epoch 75/100, Train_Loss: 1.2342,  Train_Acc: 0.5489, Val_Loss: 1.6432,  Val_Acc: 0.3846
# Epoch 76/100, Train_Loss: 1.2136,  Train_Acc: 0.5592, Val_Loss: 1.6097,  Val_Acc: 0.3948
# Epoch 77/100, Train_Loss: 1.2140,  Train_Acc: 0.5587, Val_Loss: 1.5896,  Val_Acc: 0.4069
# Epoch 78/100, Train_Loss: 1.1924,  Train_Acc: 0.5677, Val_Loss: 1.7347,  Val_Acc: 0.3855
# Epoch 79/100, Train_Loss: 1.1854,  Train_Acc: 0.5690, Val_Loss: 1.6518,  Val_Acc: 0.3845
# Epoch 80/100, Train_Loss: 1.1770,  Train_Acc: 0.5739, Val_Loss: 1.6565,  Val_Acc: 0.3961
# Epoch 81/100, Train_Loss: 1.1507,  Train_Acc: 0.5856, Val_Loss: 1.6873,  Val_Acc: 0.3931
# Epoch 82/100, Train_Loss: 1.1490,  Train_Acc: 0.5844, Val_Loss: 1.7728,  Val_Acc: 0.3681
# Epoch 83/100, Train_Loss: 1.1380,  Train_Acc: 0.5887, Val_Loss: 1.6954,  Val_Acc: 0.3890
# Epoch 84/100, Train_Loss: 1.1173,  Train_Acc: 0.5988, Val_Loss: 1.6873,  Val_Acc: 0.4001
# Epoch 85/100, Train_Loss: 1.1086,  Train_Acc: 0.6049, Val_Loss: 1.8104,  Val_Acc: 0.3923
# Epoch 86/100, Train_Loss: 1.0784,  Train_Acc: 0.6162, Val_Loss: 1.6426,  Val_Acc: 0.4008
# Epoch 87/100, Train_Loss: 1.0687,  Train_Acc: 0.6211, Val_Loss: 1.6713,  Val_Acc: 0.3972
# Epoch 88/100, Train_Loss: 1.0576,  Train_Acc: 0.6255, Val_Loss: 1.8475,  Val_Acc: 0.3826
# Epoch 89/100, Train_Loss: 1.0442,  Train_Acc: 0.6301, Val_Loss: 2.6236,  Val_Acc: 0.2959
# Epoch 90/100, Train_Loss: 1.0397,  Train_Acc: 0.6343, Val_Loss: 1.8718,  Val_Acc: 0.3749
# Epoch 91/100, Train_Loss: 1.0095,  Train_Acc: 0.6441, Val_Loss: 1.6986,  Val_Acc: 0.3947
# Epoch 92/100, Train_Loss: 1.0036,  Train_Acc: 0.6449, Val_Loss: 1.9912,  Val_Acc: 0.3816
# Epoch 93/100, Train_Loss: 0.9845,  Train_Acc: 0.6543, Val_Loss: 1.8436,  Val_Acc: 0.3845
# Epoch 94/100, Train_Loss: 0.9784,  Train_Acc: 0.6574, Val_Loss: 1.7095,  Val_Acc: 0.4067
# Epoch 95/100, Train_Loss: 0.9502,  Train_Acc: 0.6660, Val_Loss: 1.9183,  Val_Acc: 0.3901
# Epoch 96/100, Train_Loss: 0.9359,  Train_Acc: 0.6718, Val_Loss: 1.9289,  Val_Acc: 0.3892
# Epoch 97/100, Train_Loss: 0.9284,  Train_Acc: 0.6817, Val_Loss: 1.9033,  Val_Acc: 0.3785
# Epoch 98/100, Train_Loss: 0.9060,  Train_Acc: 0.6879, Val_Loss: 2.0700,  Val_Acc: 0.3501
# Epoch 99/100, Train_Loss: 0.8935,  Train_Acc: 0.6912, Val_Loss: 1.9017,  Val_Acc: 0.3874
# Epoch 100/100, Train_Loss: 0.8852,  Train_Acc: 0.6959, Val_Loss: 2.1843,  Val_Acc: 0.3514

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(train_losses, label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(train_acc, label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(val_losses, label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(val_acc, label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)
