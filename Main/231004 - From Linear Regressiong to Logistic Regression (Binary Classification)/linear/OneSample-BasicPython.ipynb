# %%
# plot data
import matplotlib.pyplot as plt

areas  = [6.7, 4.6, 3.5, 5.5]
prices = [9.1, 5.9, 4.6, 6.7]
N = len(areas)

plt.scatter(areas, prices)
plt.xlabel('Area (x 100$m^2$)')
plt.ylabel('Price (Tael)')
plt.xlim(3,7)
plt.ylim(4,10)
plt.show()

# %% [markdown]
# ####  Implementation

# %%
import random

# %%
# shuffle data
def shuffle_data(X, y):
    zip_data = list(zip(X, y))
    random.shuffle(zip_data)
    X_shuffled, y_shuffled = zip(*zip_data)

    return X_shuffled, y_shuffled

# forward
def predict(x, w, b):
    return x*w + b

# compute gradient
def gradient(y_hat, y, x):
    dw = 2*x*(y_hat-y)
    db = 2*(y_hat-y)

    return (dw, db)

# update weights
def update_weight(w, b, lr, dw, db):
    w_new = w - lr*dw
    b_new = b - lr*db

    return (w_new, b_new)

# %%
# data preparation
import numpy as np
import matplotlib.pyplot as plt

x_data = [6.7, 4.6, 3.5, 5.5]
y_data = [9.1, 5.9, 4.6, 6.7]
N = len(x_data)

print(f'areas: {x_data}')
print(f'prices: {y_data}')
print(f'data_size: {N}')
# Out:
# areas: [6.7, 4.6, 3.5, 5.5]
# prices: [9.1, 5.9, 4.6, 6.7]
# data_size: 4

# %%
# init weights
b = 0.04
w = -0.34
lr = 0.005

# parameter
epoch_max = 30
losses = [] # monitoring

for epoch in range(epoch_max):
    # shuffle data
    x_data_sh, y_data_sh = shuffle_data(x_data, y_data)

    # for an epoch
    for i in range(N):

        # get a sample
        x = x_data_sh[i]
        y = y_data_sh[i]

        # predict y_hat
        y_hat = predict(x, w, b)

        # compute loss
        loss = (y_hat-y)*(y_hat-y)

        # for debug
        losses.append(loss)
        print(loss)

        # compute gradient
        (dw, db) = gradient(y_hat, y, x)

        # update weights
        (w, b) = update_weight(w, b, lr, dw, db)
# Out:
# 33.0625
# 98.64710701562498
# 10.760681852982234
# 7.527254314754921
# 2.0828411251803876
# 2.512453302337186
# 1.3855435966317322
# 3.9571432352847173
# 0.08483443851967809
# 0.0004115174068374467
# 0.04431054651863621
# 0.8834452342801327
# 0.25866323222314347
# 0.029429619246933957
# 0.3250070413219292
# 0.007324967463839732
# 0.0044382458381271445
# 0.12384017059122393
# 0.5105847116005108
# 0.012275588596614153
# 0.009238070920810608
# 0.02288982234843322
# 0.1855077020226514
# 0.42041946008555237
# 0.04444150694073571
# 0.008607179028219294
# 0.19413861621841963
# 0.4020448414535505
# 0.19002900709327872
# 0.4139730747923779
# 0.016602641180055326
# 0.03599530113922924
# 0.021809789089434536
# 0.00292487148716888
# 0.2502374724389584
# 0.36818810165957244
# 0.17402640742503273
# 1.95019216024073e-05
# 0.001396548580410509
# 0.41951682630987835
# 0.12283000015697709
# 0.10276594358786524
# 0.3469535861308915
# 0.0014091385506146044
# 0.15789097398352908
# 0.0002658541098338585
# 0.44753614840069167
# 0.014031440434223922
# 0.03237205299493232
# 0.2008825573669621
# 0.39566120090355056
# 0.0029377934451231364
# 0.011657281589521576
# 0.15450947645318822
# 0.0026051869234666528
# 0.4415751624384512
# 0.2831237039318165
# 0.3146811549858426
# 0.021786274061863568
# 0.04586347657921501
# 0.24199185357707315
# 6.710215013073548e-05
# 0.001499572983984712
# 0.36516028664871353
# 0.31180580131195845
# 0.28980066103525
# 0.023276532741444204
# 0.04874229424519968
# 0.2486982404679253
# 4.079908828413271e-05
# 0.3434424493826475
# 0.05210507056998073
# 0.15189732935294376
# 0.09102110551513226
# 0.020281601033204328
# 0.29730967150088106
# 0.3004024080760548
# 0.33909540739620514
# 0.0008536144740279732
# 0.0069456927166431
# 0.303206223434654
# 0.05764160835179233
# 0.26810064516236337
# 3.242893639163205e-08
# 0.12674540918546925
# 0.4970759392023937
# 0.03292337276765781
# 0.0047754776636765375
# 0.003593815562535214
# 0.19163482471681137
# 1.6320167783791424e-05
# 0.40674214158618366
# 0.014066192142720783
# 0.03452169252832354
# 0.18767377592831547
# 0.39990555812357637
# 0.01349294564235775
# 0.16338733358096233
# 0.002781305698877339
# 0.42357903354088144
# 0.040089121144826705
# 0.23257046952365354
# 0.00034289098744369695
# 0.3526945948077483
# 0.01667717142668048
# 0.03963146492923402
# 0.23191585463194372
# 0.35825800491787707
# 0.10489407823608063
# 0.4626989932404277
# 0.0046587386875073244
# 0.01722689026628264
# 0.2412417427902679
# 0.06679859890600402
# 0.012692511611363526
# 0.26463671347410184
# 4.145194977755801e-05
# 0.0022773890272233532
# 0.11725316119066002
# 0.5090587153406515

# %%
# get result
print(w, b)
# Out:
# 1.2570542543193406 0.29167057020292214

# %%
import matplotlib.pyplot as plt
plt.plot(losses)

# %%
import matplotlib.pyplot as plt
plt.plot(losses[-10:])

# %%
area_real = 6
predicted_price = area_real*w + b
print('predicted_price: ', predicted_price)
# Out:
# predicted_price:  7.833996096118965

# %%
#x_data = range(2, 8)
y_data = [x*w + b for x in x_data]
plt.plot(x_data, y_data, 'r')
plt.scatter(areas, prices)
